# %% [markdown]
# # Correlation networks across bands (single patient)
#
# Figure C/B: Correlation matrices per band for one patient and one phase.
#
# **Legacy notebooks merged:**
# - pat02_corrnet_bands.ipynb

# %%
# %matplotlib inline
from lrgsglib.config.funcs import move_to_rootf
move_to_rootf(pathname="lrg_eegfc")
from lrg_eegfc.notebook import *

# %%
DATA_ROOT = Path('data/stereoeeg_patients')
patients = list_patients(DATA_ROOT)
assert patients, 'No patients found under data/stereoeeg_patients'

patient = patients[0]
phase = PHASE_LABELS[0]

import matplotlib.pyplot as plt

for band in BRAIN_BANDS_NAMES:
    corr = load_corr_matrix(patient, phase, band, filter_type='abs', zero_diagonal=True)
    if corr is None:
        print(f"Missing corr cache for {band}")
        continue
    fig, ax = plt.subplots(figsize=(4, 4))
    im = ax.imshow(corr, cmap='viridis', vmin=0, vmax=1)
    ax.set_title(f"{patient} {phase} {band}")
    fig.colorbar(im, ax=ax, shrink=0.8)
    plt.show()
