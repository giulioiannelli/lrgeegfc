# %% [markdown]
# # LRG full panel (single patient)
#
# Figures M/N: LRG entropy, dendrogram, PSI, and network panel.
#
# **Legacy notebooks merged:**
# - FIGMNTGN01.ipynb
# - FIGMNTGN02.ipynb
# - FIGMNTGN03.ipynb

# %%
# %matplotlib inline
from lrgsglib.config.funcs import move_to_rootf
move_to_rootf(pathname="lrg_eegfc")
from lrg_eegfc.notebook import *

# %%
patient = list_patients(Path('data/stereoeeg_patients'))[0]
phase = PHASE_LABELS[0]
band = BRAIN_BANDS_NAMES[2]
fc_method = 'msc'

plot_lrg_full_panel(patient, phase, band, fc_method, cache_root=Path('data/lrg_cache'))
