# %% [markdown]
# # What ARE the Most Metastable Nodes?
#
# **Flipped question**: Instead of asking "are epileptic nodes metastable?", ask:
# "what ARE the most metastable nodes? What characterizes them? Do they have any clinical or anatomical meaning?"
#
# Uses the Desikan-Killiany atlas column from implant Excel files to give anatomical labels.
#
# Checks whether metastable nodes are:
# 1. At **probe boundaries** (first/last contacts on a depth electrode)
# 2. At **community boundaries** (high participation coefficient)
# 3. In specific **anatomical regions**
# 4. **Epileptic** nodes

# %%
# Setup
from lrgsglib.config.funcs import move_to_rootf
move_to_rootf(pathname='lrgeegfc')

import numpy as np
import pandas as pd
import re
import warnings
import openpyxl
from pathlib import Path
from collections import Counter
from scipy.cluster.hierarchy import fcluster

warnings.filterwarnings('ignore')

from lrg_eegfc.workflow.msc import load_msc_matrix
from lrg_eegfc.workflow.diagnostics import compute_coarsening_and_metastability
from lrg_eegfc.utils.io import load_epileptic_nodes
# Out:
# Current working directory: /home/giulio/Documents/research/neural_networks/lrgeegfc

# %%
# ── Helper functions ──────────────────────────────────────────────────────

def load_ch(patient):
    """Load channel labels, stripping spaces to match Excel format."""
    path = Path(f'data/stereoeeg_patients/{patient}/channel_labels.csv')
    with open(path) as f:
        first = f.readline().strip()
    if first.lower() == 'label':
        df = pd.read_csv(path, header=None, skiprows=1)
    else:
        df = pd.read_csv(path, header=None)
    return [str(l).strip('"').split(',')[0].strip().replace(' ', '') for l in df.iloc[:, 0]]


def get_probe(label):
    """Extract probe letter prefix from electrode label (e.g., 'A' from 'A3')."""
    m = re.match(r"([A-Za-z]+'?)", label)
    return m.group(1) if m else label


def load_implant_anatomy(patient):
    """Load anatomical labels from implant Excel file (Desikan-Killiany column)."""
    patnum = int(patient.split('_')[1])
    candidates = [
        Path(f'data/stereoeeg_patients/{patient}/Implant_pat_{patnum}.xlsx'),
        Path(f'data/stereoeeg_patients/{patient}/Implant_locations/Implant_pat_{patnum}.xlsx'),
    ]
    xlsx = next((c for c in candidates if c.exists()), None)
    if xlsx is None:
        return {}
    wb = openpyxl.load_workbook(xlsx, data_only=True)
    for name in ('all_leads', 'ALL_LEADS'):
        if name in wb.sheetnames:
            ws = wb[name]
            break
    else:
        ws = wb.active

    anatomy = {}
    for row in range(2, ws.max_row + 1):
        label = ws.cell(row, 1).value
        dk = ws.cell(row, 5).value  # Desikan-Killiany column
        if label and dk:
            clean_label = str(label).strip().replace(' ', '')
            anatomy[clean_label] = str(dk).strip()
    return anatomy

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %% [markdown]
# ## Main Analysis: Per-patient, per-band metastability characterization

# %%
# ── Configuration ─────────────────────────────────────────────────────────
patients = ['Pat_02', 'Pat_03', 'Pat_05', 'Pat_07', 'Pat_08']
bands = ['delta', 'theta', 'alpha', 'beta']
TOP_K = 15  # number of top metastable nodes to inspect

# Collectors for cross-patient aggregation
all_rows = []  # one row per (patient, band, node-in-top-K)

for patient in patients:
    epi_set = set(load_epileptic_nodes(patient))
    ch = load_ch(patient)
    N = len(ch)
    epi_mask = np.array([l in epi_set for l in ch])
    anatomy = load_implant_anatomy(patient)

    print(f"\n{'=' * 80}")
    print(f"{patient}  ({N} channels, {sum(epi_mask)} epileptic, "
          f"{len(anatomy)} anatomy labels)")
    print(f"{'=' * 80}")

    for band in bands:
        A = load_msc_matrix(patient, 'rsPre', band,
                            cache_root=Path('data/msc_cache'),
                            sparsify='none', n_surrogates=0, nperseg=4096)
        if A is None or A.shape[0] != N:
            print(f"  {band}: SKIP (matrix mismatch or missing)")
            continue

        # Build Laplacian
        A_copy = A.copy()
        np.fill_diagonal(A_copy, 0)
        D = A_copy.sum(axis=1)
        L = np.diag(D) - A_copy
        evals, evecs = np.linalg.eigh(L)
        evals = np.maximum(evals, 0.0)
        if evals[1] < 1e-10:
            print(f"  {band}: SKIP (disconnected graph)")
            continue

        # Compute metastability
        result = compute_coarsening_and_metastability(evals, evecs, n_tau=40)
        mu = result['mu']

        # Top K most metastable
        top = np.argsort(mu)[::-1][:TOP_K]

        print(f"\n  rsPre/{band} -- Top {TOP_K} metastable nodes:")
        print(f"    {'#':>3s} {'label':>8s} {'probe':>6s} {'mu':>6s} "
              f"{'epi':>4s} {'strength':>8s} {'anatomy':>40s}")
        for rank, idx in enumerate(top):
            lbl = ch[idx]
            probe = get_probe(lbl)
            is_epi = 'EPI' if lbl in epi_set else ''
            strength = D[idx]
            anat = anatomy.get(lbl, '?')
            print(f"    {rank+1:3d} {lbl:>8s} {probe:>6s} {mu[idx]:6.3f} "
                  f"{is_epi:>4s} {strength:8.2f} {anat[:40]:>40s}")

            all_rows.append(dict(
                patient=patient, band=band, rank=rank + 1,
                label=lbl, probe=probe, mu=mu[idx],
                is_epi=lbl in epi_set, strength=strength,
                anatomy=anat,
            ))

        # ── Probe boundary analysis ──
        boundary_count = 0
        for idx in top:
            lbl = ch[idx]
            probe = get_probe(lbl)
            probe_contacts = sorted(
                [ch[i] for i in range(N) if get_probe(ch[i]) == probe])
            if lbl == probe_contacts[0] or lbl == probe_contacts[-1]:
                boundary_count += 1
        print(f"    Probe boundary contacts (first/last): {boundary_count}/{TOP_K}")

        # ── Probe distribution ──
        top_probes = [get_probe(ch[i]) for i in top]
        probe_counts = Counter(top_probes)
        print(f"    Probes represented: {dict(probe_counts)}")

        # ── Community boundary analysis (via LRG cache) ──
        lrg_path = Path(f'data/lrg_cache/{patient}/{band}_rsPre_lrg_msc.npz')
        if lrg_path.exists():
            lrg = np.load(lrg_path, allow_pickle=True)
            Z = lrg['linkage_matrix']
            thresh = float(lrg['optimal_threshold'])
            n_nodes_lrg = int(lrg['n_nodes'])
            if n_nodes_lrg == N:
                labels_opt = fcluster(Z, thresh, criterion='distance')
                n_comm = len(np.unique(labels_opt))

                # Participation coefficient
                pc = np.zeros(N)
                for i in range(N):
                    si = A_copy[i].sum()
                    if si == 0:
                        continue
                    for c in np.unique(labels_opt):
                        pc[i] += (A_copy[i, labels_opt == c].sum() / si) ** 2
                pc = 1 - pc

                top_mask = np.zeros(N, dtype=bool)
                top_mask[top] = True

                # Community boundary nodes: have strong neighbors in >1 community
                boundary_nodes = 0
                for idx in top:
                    nonzero = A_copy[idx][A_copy[idx] > 0]
                    if len(nonzero) == 0:
                        continue
                    thresh50 = np.percentile(nonzero, 50)
                    neighbor_comms = set(
                        labels_opt[A_copy[idx] > thresh50])
                    if len(neighbor_comms) > 1:
                        boundary_nodes += 1

                print(f"    Community boundary nodes: {boundary_nodes}/{TOP_K} "
                      f"(n*={n_comm})")
                print(f"    Participation coeff: top_meta={pc[top_mask].mean():.3f} "
                      f"vs others={pc[~top_mask].mean():.3f}")

print("\n\nPer-patient analysis complete.")
# Out:
# ================================================================================
# Pat_02  (117 channels, 14 epileptic, 209 anatomy labels)
# ================================================================================
#
#   rsPre/delta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       L6      L  1.000         12.39 ctx-lh-fusiform,50.0,Wm,38.0,ctx-lh-infe
#       2       L5      L  1.000         11.04 Wm,72.0,ctx-lh-fusiform,16.0,Amy,6.0,PTD
#       3       F3      F  0.667          4.15 ctx-lh-lateralorbitofrontal,45.0,ctx-lh-
#       4       F2      F  0.667          4.46 ctx-lh-medialorbitofrontal,57.0,Wm,41.0,
#       5       B9      B  0.667  EPI     5.86 ctx-lh-inferiortemporal,72.0,Wm,21.0,Unk
#       6       B8      B  0.667  EPI     4.54 ctx-lh-inferiortemporal,57.0,Wm,43.0,PTD
#       7       A8      A  0.667          4.21 ctx-lh-fusiform,79.0,ctx-lh-inferiortemp
#       8       B4      B  0.667          9.36  Wm,59.0,ctx-lh-fusiform,41.0,PTD, -0.19
#       9       B3      B  0.667         10.33   ctx-lh-fusiform,67.0,Wm,33.0,PTD, 0.33
#      10       B2      B  0.667         12.65 ctx-lh-fusiform,76.0,Unk,11.0,ctx-lh-lin
#      11       F1      F  0.667          5.72 ctx-lh-medialorbitofrontal,79.0,Wm,14.0,
#      12      B10      B  0.667  EPI     6.26 ctx-lh-inferiortemporal,87.0,Unk,7.0,Wm,
#      13       A9      A  0.667          6.00 ctx-lh-fusiform,45.0,Unk,39.0,ctx-lh-inf
#      14       B1      B  0.667         11.25 Cerebellum-Cortex,30.0,ctx-lh-parahippoc
#      15       M8      M  0.667          9.07 ctx-lh-superiortemporal,49.0,ctx-lh-midd
#     Probe boundary contacts (first/last): 5/15
#     Probes represented: {'L': 2, 'F': 3, 'B': 7, 'A': 2, 'M': 1}
#     Community boundary nodes: 15/15 (n*=4)
#     Participation coeff: top_meta=0.249 vs others=0.363
#
#   rsPre/theta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       M3      M  0.750         15.50 ctx-lh-superiortemporal,55.0,Wm,44.0,Unk
#       2      F14      F  0.750         19.70 Unk,86.0,ctx-lh-parsorbitalis,14.0,PTD,
#       3       N4      N  0.750          7.77 ctx-lh-bankssts,62.0,Unk,37.0,Wm,1.0,PTD
#       4      H16      H  0.750         21.62                      Unk,100.0,PTD, 1.00
#       5      L12      L  0.750         14.59 Unk,67.0,ctx-lh-middletemporal,33.0,PTD,
#       6      Q10      Q  0.500          5.20 Wm,59.0,ctx-lh-lateraloccipital,22.0,ctx
#       7       A8      A  0.500          7.08 ctx-lh-fusiform,79.0,ctx-lh-inferiortemp
#       8       A5      A  0.500         11.26   ctx-lh-fusiform,52.0,Wm,48.0,PTD, 0.04
#       9       F4      F  0.500         10.09 ctx-lh-lateralorbitofrontal,50.0,Wm,48.0
#      10       N8      N  0.500         15.08 ctx-lh-middletemporal,50.0,ctx-lh-superi
#      11       B1      B  0.500         15.89 Cerebellum-Cortex,30.0,ctx-lh-parahippoc
#      12       F1      F  0.500         10.06 ctx-lh-medialorbitofrontal,79.0,Wm,14.0,
#      13       M8      M  0.500         16.05 ctx-lh-superiortemporal,49.0,ctx-lh-midd
#      14       F8      F  0.500         11.77 ctx-lh-lateralorbitofrontal,65.0,Wm,35.0
#      15      G12      G  0.500         15.02 Unk,51.0,ctx-lh-middletemporal,45.0,ctx-
#     Probe boundary contacts (first/last): 5/15
#     Probes represented: {'M': 2, 'F': 4, 'N': 2, 'H': 1, 'L': 1, 'Q': 1, 'A': 2, 'B': 1, 'G': 1}
#     Community boundary nodes: 15/15 (n*=3)
#     Participation coeff: top_meta=0.192 vs others=0.270
#
#   rsPre/alpha -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       L7      L  0.750         12.85 Wm,64.0,ctx-lh-inferiortemporal,28.0,ctx
#       2       F8      F  0.750          9.31 ctx-lh-lateralorbitofrontal,65.0,Wm,35.0
#       3       P1      P  0.500          1.82 ctx-lh-isthmuscingulate,72.0,ctx-lh-prec
#       4       N4      N  0.500          5.48 ctx-lh-bankssts,62.0,Unk,37.0,Wm,1.0,PTD
#       5       F3      F  0.500          6.00 ctx-lh-lateralorbitofrontal,45.0,ctx-lh-
#       6       F4      F  0.500          7.63 ctx-lh-lateralorbitofrontal,50.0,Wm,48.0
#       7      H14      H  0.500         13.00 Unk,72.0,ctx-lh-middletemporal,28.0,PTD,
#       8      H16      H  0.500         16.76                      Unk,100.0,PTD, 1.00
#       9       M5      M  0.500          6.16 ctx-lh-superiortemporal,79.0,ctx-lh-midd
#      10       M4      M  0.500          7.38 ctx-lh-superiortemporal,68.0,Wm,28.0,ctx
#      11       M3      M  0.500          9.56 ctx-lh-superiortemporal,55.0,Wm,44.0,Unk
#      12       G7      G  0.500          7.43 Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD
#      13      F14      F  0.500         16.02 Unk,86.0,ctx-lh-parsorbitalis,14.0,PTD,
#      14       G6      G  0.500          9.01 Wm,54.0,ctx-lh-inferiortemporal,29.0,ctx
#      15       G3      G  0.500  EPI     3.39 Wm,57.0,Hip,23.0,ctx-lh-parahippocampal,
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'L': 1, 'F': 4, 'P': 1, 'N': 1, 'H': 2, 'M': 3, 'G': 3}
#     Community boundary nodes: 6/15 (n*=3)
#     Participation coeff: top_meta=0.069 vs others=0.120
#
#   rsPre/beta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       N1      N  0.444          7.14                      Wm,100.0,PTD, -1.00
#       2       N2      N  0.444          5.45   ctx-lh-bankssts,52.0,Wm,48.0,PTD, 0.04
#       3      H16      H  0.333         17.53                      Unk,100.0,PTD, 1.00
#       4       L8      L  0.333         16.73 Wm,46.0,ctx-lh-inferiortemporal,44.0,ctx
#       5       B3      B  0.333         14.40   ctx-lh-fusiform,67.0,Wm,33.0,PTD, 0.33
#       6       B4      B  0.333         13.54  Wm,59.0,ctx-lh-fusiform,41.0,PTD, -0.19
#       7      L12      L  0.333         14.29 Unk,67.0,ctx-lh-middletemporal,33.0,PTD,
#       8       B6      B  0.222          8.67 ctx-lh-fusiform,66.0,ctx-lh-inferiortemp
#       9       B5      B  0.222         12.99 ctx-lh-fusiform,53.0,Wm,46.0,Unk,1.0,PTD
#      10       F8      F  0.222          5.86 ctx-lh-lateralorbitofrontal,65.0,Wm,35.0
#      11      F12      F  0.222         11.38 Unk,40.0,ctx-lh-parsorbitalis,34.0,ctx-l
#      12       F4      F  0.222          6.97 ctx-lh-lateralorbitofrontal,50.0,Wm,48.0
#      13       F3      F  0.222          7.08 ctx-lh-lateralorbitofrontal,45.0,ctx-lh-
#      14       N3      N  0.222          4.20 ctx-lh-bankssts,76.0,Unk,24.0,Wm,1.0,PTD
#      15       G7      G  0.222         15.07 Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'N': 3, 'H': 1, 'L': 2, 'B': 4, 'F': 4, 'G': 1}
#     Community boundary nodes: 0/15 (n*=3)
#     Participation coeff: top_meta=0.018 vs others=0.087
#
# ================================================================================
# Pat_03  (122 channels, 6 epileptic, 221 anatomy labels)
# ================================================================================
#
#   rsPre/delta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       H2      H  1.000          5.12 ctx-lh-precuneus,47.0,ctx-lh-cuneus,23.0
#       2       H1      H  1.000          4.76 ctx-lh-precuneus,50.0,Unk,30.0,ctx-lh-cu
#       3      B15      B  1.000          4.76 ctx-lh-middletemporal,76.0,Unk,24.0,PTD,
#       4       H3      H  1.000          3.32 Unk,37.0,ctx-lh-precuneus,22.0,ctx-lh-cu
#       5       P4      P  1.000          8.29 ctx-lh-precuneus,77.0,Unk,14.0,ctx-lh-cu
#       6       P3      P  1.000          3.93 ctx-lh-cuneus,60.0,ctx-lh-precuneus,25.0
#       7       H4      H  1.000          4.19 Unk,32.0,ctx-lh-precuneus,31.0,ctx-lh-cu
#       8      D10      D  0.000         29.18 ctx-lh-middletemporal,92.0,Wm,8.0,PTD, 0
#       9       D8      D  0.000         16.47 ctx-lh-inferiortemporal,46.0,ctx-lh-midd
#      10       D7      D  0.000         22.88 ctx-lh-inferiortemporal,57.0,ctx-lh-midd
#      11       D6      D  0.000         42.16 ctx-lh-inferiortemporal,85.0,ctx-lh-midd
#      12       D5      D  0.000         41.91 Wm,54.0,ctx-lh-inferiortemporal,34.0,ctx
#      13       D4      D  0.000         42.95 Wm,65.0,ctx-lh-fusiform,34.0,ctx-lh-infe
#      14       D3      D  0.000         35.81 Wm,85.0,ctx-lh-fusiform,7.0,ctx-lh-entor
#      15       D2      D  0.000         31.03 ctx-lh-entorhinal,59.0,Wm,32.0,ctx-lh-fu
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'H': 4, 'B': 1, 'P': 2, 'D': 8}
#     Community boundary nodes: 6/15 (n*=5)
#     Participation coeff: top_meta=0.164 vs others=0.046
#
#   rsPre/theta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       Y1      Y  0.600         19.71 ctx-lh-precuneus,71.0,ctx-rh-precuneus,1
#       2       A4      A  0.400         19.29 Wm,70.0,ctx-lh-lingual,28.0,Unk,2.0,PTD,
#       3       A5      A  0.400         23.42 ctx-lh-lingual,53.0,ctx-lh-fusiform,29.0
#       4       A6      A  0.400         30.38 ctx-lh-fusiform,60.0,Wm,25.0,ctx-lh-ling
#       5       B2      B  0.400         19.64                      Hip,100.0,PTD, 1.00
#       6       P3      P  0.400          8.86 ctx-lh-cuneus,60.0,ctx-lh-precuneus,25.0
#       7       P4      P  0.400         13.08 ctx-lh-precuneus,77.0,Unk,14.0,ctx-lh-cu
#       8       P5      P  0.400         16.79 ctx-lh-precuneus,56.0,Wm,41.0,Unk,3.0,PT
#       9       Y2      Y  0.400         11.61 Wm,61.0,ctx-lh-precuneus,39.0,PTD, -0.22
#      10       Y3      Y  0.400         13.79 ctx-lh-precuneus,84.0,Wm,15.0,Unk,2.0,PT
#      11       E7      E  0.400         45.56 Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD
#      12       B4      B  0.400         24.67                Hip,99.0,Wm,1.0,PTD, 0.98
#      13       B5      B  0.400         30.98               Hip,81.0,Wm,19.0,PTD, 0.63
#      14       P1      P  0.400         10.34 ctx-lh-cuneus,65.0,Wm,30.0,Unk,4.0,ctx-r
#      15       P2      P  0.400         14.47     ctx-lh-cuneus,60.0,Wm,40.0,PTD, 0.20
#     Probe boundary contacts (first/last): 4/15
#     Probes represented: {'Y': 3, 'A': 3, 'B': 3, 'P': 5, 'E': 1}
#     Community boundary nodes: 5/15 (n*=3)
#     Participation coeff: top_meta=0.068 vs others=0.062
#
#   rsPre/alpha -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1      P10      P  1.000          8.14 ctx-lh-inferiorparietal,73.0,Wm,17.0,Unk
#       2       P9      P  1.000          5.72 ctx-lh-inferiorparietal,52.0,Wm,40.0,Unk
#       3       P8      P  1.000          5.24 ctx-lh-inferiorparietal,60.0,Wm,33.0,Unk
#       4       O1      O  1.000  EPI     2.69 ctx-lh-cuneus,37.0,Unk,27.0,Wm,24.0,ctx-
#       5      D10      D  0.000         25.72 ctx-lh-middletemporal,92.0,Wm,8.0,PTD, 0
#       6       D9      D  0.000         17.98 ctx-lh-middletemporal,68.0,ctx-lh-inferi
#       7       D8      D  0.000         16.05 ctx-lh-inferiortemporal,46.0,ctx-lh-midd
#       8       D7      D  0.000         19.93 ctx-lh-inferiortemporal,57.0,ctx-lh-midd
#       9       D6      D  0.000         33.81 ctx-lh-inferiortemporal,85.0,ctx-lh-midd
#      10       D5      D  0.000         35.21 Wm,54.0,ctx-lh-inferiortemporal,34.0,ctx
#      11       D4      D  0.000         37.02 Wm,65.0,ctx-lh-fusiform,34.0,ctx-lh-infe
#      12      D11      D  0.000         28.29 ctx-lh-middletemporal,87.0,Unk,13.0,PTD,
#      13       D2      D  0.000         25.30 ctx-lh-entorhinal,59.0,Wm,32.0,ctx-lh-fu
#      14       D1      D  0.000         23.68 ctx-lh-entorhinal,92.0,Wm,7.0,Unk,2.0,PT
#      15      C13      C  0.000         26.38 ctx-lh-middletemporal,79.0,Wm,21.0,PTD,
#     Probe boundary contacts (first/last): 4/15
#     Probes represented: {'P': 3, 'O': 1, 'D': 10, 'C': 1}
#     Community boundary nodes: 1/15 (n*=3)
#     Participation coeff: top_meta=0.028 vs others=0.063
#
#   rsPre/beta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       E7      E  0.333         21.99 Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD
#       2       E6      E  0.333         21.26 ctx-lh-inferiortemporal,66.0,Wm,33.0,Unk
#       3       F7      F  0.333         24.13 Wm,50.0,ctx-lh-fusiform,46.0,ctx-lh-infe
#       4       A9      A  0.250         18.04 Wm,78.0,ctx-lh-lateraloccipital,22.0,PTD
#       5       F8      F  0.250         24.59 Wm,60.0,ctx-lh-inferiortemporal,36.0,ctx
#       6      A10      A  0.250         13.95 Wm,62.0,ctx-lh-lateraloccipital,24.0,ctx
#       7       P3      P  0.250          4.15 ctx-lh-cuneus,60.0,ctx-lh-precuneus,25.0
#       8       P4      P  0.250          4.91 ctx-lh-precuneus,77.0,Unk,14.0,ctx-lh-cu
#       9      A11      A  0.250         12.56 Wm,59.0,ctx-lh-inferiortemporal,41.0,PTD
#      10       D9      D  0.250         10.02 ctx-lh-middletemporal,68.0,ctx-lh-inferi
#      11       C1      C  0.167          7.48 Hip,91.0,Thalamus-Proper,5.0,Wm,4.0,PTD,
#      12      B14      B  0.167         13.83 ctx-lh-middletemporal,76.0,Wm,24.0,PTD,
#      13      B13      B  0.167         15.21 Wm,55.0,ctx-lh-middletemporal,45.0,PTD,
#      14      B12      B  0.167         15.77 Wm,51.0,ctx-lh-middletemporal,49.0,PTD,
#      15       L6      L  0.167          9.60 Wm,93.0,ctx-lh-pericalcarine,7.0,PTD, -0
#     Probe boundary contacts (first/last): 4/15
#     Probes represented: {'E': 2, 'F': 2, 'A': 3, 'P': 2, 'D': 1, 'C': 1, 'B': 3, 'L': 1}
#     Community boundary nodes: 13/15 (n*=14)
#     Participation coeff: top_meta=0.275 vs others=0.312
#
# ================================================================================
# Pat_05  (118 channels, 14 epileptic, 193 anatomy labels)
# ================================================================================
#
#   rsPre/delta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1      G13      G  1.000         83.58 ctx-rh-superiorfrontal,49.0,Wm,46.0,Unk,
#       2       Y1      Y  1.000  EPI    78.80 ctx-rh-superiorfrontal,63.0,Unk,24.0,Wm,
#       3       Y2      Y  1.000  EPI    72.80 ctx-rh-superiorfrontal,54.0,Wm,41.0,Unk,
#       4       Y3      Y  1.000         79.75 Wm,59.0,ctx-rh-superiorfrontal,34.0,Unk,
#       5       Y4      Y  1.000         85.23 Wm,90.0,ctx-rh-superiorfrontal,10.0,PTD,
#       6       Y5      Y  1.000         82.60 Wm,53.0,ctx-rh-superiorfrontal,46.0,Unk,
#       7       Y6      Y  1.000         76.95 ctx-rh-superiorfrontal,45.0,ctx-rh-rostr
#       8     Y'10     Y'  1.000         63.96 ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,
#       9      Y'9     Y'  1.000         66.93 ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,
#      10       O3      O  0.500         73.97 Wm,56.0,ctx-rh-lateralorbitofrontal,44.0
#      11      O10      O  0.500         81.80 ctx-rh-rostralmiddlefrontal,50.0,Wm,41.0
#      12      O11      O  0.500         74.17 ctx-rh-rostralmiddlefrontal,65.0,Wm,20.0
#      13      O12      O  0.500         67.41 ctx-rh-rostralmiddlefrontal,59.0,Wm,36.0
#      14      O13      O  0.500         68.11 ctx-rh-rostralmiddlefrontal,76.0,Unk,20.
#      15       Y7      Y  0.500         66.87 ctx-rh-rostralmiddlefrontal,50.0,Wm,35.0
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'G': 1, 'Y': 7, "Y'": 2, 'O': 5}
#     Community boundary nodes: 15/15 (n*=118)
#     Participation coeff: top_meta=0.991 vs others=0.991
#
#   rsPre/theta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       F1      F  1.000         30.81 ctx-rh-medialorbitofrontal,68.0,Unk,31.0
#       2     X'11     X'  1.000         58.67 ctx-lh-rostralmiddlefrontal,79.0,Wm,21.0
#       3     X'10     X'  1.000         51.78 Wm,59.0,ctx-lh-rostralmiddlefrontal,41.0
#       4      X'9     X'  1.000         43.86 Wm,68.0,ctx-lh-rostralmiddlefrontal,32.0
#       5      X'8     X'  1.000         48.20 ctx-lh-rostralmiddlefrontal,55.0,Wm,37.0
#       6       G9      G  1.000         48.38 ctx-rh-medialorbitofrontal,52.0,ctx-rh-r
#       7       G8      G  1.000         48.11 ctx-rh-medialorbitofrontal,53.0,ctx-rh-r
#       8       G7      G  1.000         51.55 ctx-rh-rostralanteriorcingulate,56.0,Wm,
#       9       G6      G  1.000         49.76 ctx-rh-rostralanteriorcingulate,45.0,ctx
#      10       G5      G  1.000         50.53 ctx-rh-medialorbitofrontal,63.0,ctx-rh-r
#      11       G4      G  1.000         38.06 ctx-rh-medialorbitofrontal,55.0,Wm,44.0,
#      12       G3      G  1.000         46.19 Wm,50.0,ctx-rh-medialorbitofrontal,50.0,
#      13       G2      G  1.000         35.07 ctx-rh-medialorbitofrontal,61.0,Wm,37.0,
#      14     Y'10     Y'  1.000         36.20 ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,
#      15      Y'9     Y'  1.000         37.12 ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,
#     Probe boundary contacts (first/last): 4/15
#     Probes represented: {'F': 1, "X'": 4, 'G': 8, "Y'": 2}
#     Community boundary nodes: 15/15 (n*=6)
#     Participation coeff: top_meta=0.210 vs others=0.221
#
#   rsPre/alpha -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       F1      F  1.000         15.31 ctx-rh-medialorbitofrontal,68.0,Unk,31.0
#       2     X'11     X'  1.000         34.87 ctx-lh-rostralmiddlefrontal,79.0,Wm,21.0
#       3     X'10     X'  1.000         26.09 Wm,59.0,ctx-lh-rostralmiddlefrontal,41.0
#       4      X'9     X'  1.000         24.19 Wm,68.0,ctx-lh-rostralmiddlefrontal,32.0
#       5      X'8     X'  1.000         26.14 ctx-lh-rostralmiddlefrontal,55.0,Wm,37.0
#       6       G9      G  1.000         27.24 ctx-rh-medialorbitofrontal,52.0,ctx-rh-r
#       7       G8      G  1.000         24.87 ctx-rh-medialorbitofrontal,53.0,ctx-rh-r
#       8       G7      G  1.000         25.37 ctx-rh-rostralanteriorcingulate,56.0,Wm,
#       9       G6      G  1.000         27.44 ctx-rh-rostralanteriorcingulate,45.0,ctx
#      10       G5      G  1.000         28.49 ctx-rh-medialorbitofrontal,63.0,ctx-rh-r
#      11       G4      G  1.000         23.13 ctx-rh-medialorbitofrontal,55.0,Wm,44.0,
#      12       G3      G  1.000         26.17 Wm,50.0,ctx-rh-medialorbitofrontal,50.0,
#      13       G2      G  1.000         21.08 ctx-rh-medialorbitofrontal,61.0,Wm,37.0,
#      14     Y'10     Y'  1.000         17.93 ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,
#      15      Y'9     Y'  1.000         15.83 ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,
#     Probe boundary contacts (first/last): 4/15
#     Probes represented: {'F': 1, "X'": 4, 'G': 8, "Y'": 2}
#     Community boundary nodes: 12/15 (n*=3)
#     Participation coeff: top_meta=0.075 vs others=0.089
#
#   rsPre/beta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1      G13      G  0.333          9.49 ctx-rh-superiorfrontal,49.0,Wm,46.0,Unk,
#       2       F3      F  0.333          6.75 Wm,54.0,ctx-rh-medialorbitofrontal,44.0,
#       3      X'6     X'  0.333          8.96 ctx-lh-superiorfrontal,53.0,Wm,47.0,PTD,
#       4       F8      F  0.333          3.70 ctx-rh-rostralmiddlefrontal,51.0,Wm,43.0
#       5       X9      X  0.333          7.66 ctx-rh-rostralmiddlefrontal,82.0,Wm,9.0,
#       6      X'5     X'  0.333         11.92 Wm,88.0,ctx-lh-superiorfrontal,12.0,PTD,
#       7     L'10     L'  0.333          8.50 Wm,57.0,ctx-lh-caudalmiddlefrontal,38.0,
#       8      X'8     X'  0.333          7.91 ctx-lh-rostralmiddlefrontal,55.0,Wm,37.0
#       9     G'18     G'  0.333         16.86 Unk,62.0,ctx-lh-superiorfrontal,35.0,ctx
#      10      O11      O  0.333          3.60 ctx-rh-rostralmiddlefrontal,65.0,Wm,20.0
#      11       G9      G  0.333          9.63 ctx-rh-medialorbitofrontal,52.0,ctx-rh-r
#      12      O10      O  0.333          3.50 ctx-rh-rostralmiddlefrontal,50.0,Wm,41.0
#      13      X'7     X'  0.333          7.28 ctx-lh-superiorfrontal,51.0,ctx-lh-rostr
#      14       Y5      Y  0.333          6.80 Wm,53.0,ctx-rh-superiorfrontal,46.0,Unk,
#      15       Y4      Y  0.333          9.26 Wm,90.0,ctx-rh-superiorfrontal,10.0,PTD,
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'G': 2, 'F': 2, "X'": 4, 'X': 1, "L'": 1, "G'": 1, 'O': 2, 'Y': 2}
#     Community boundary nodes: 15/15 (n*=6)
#     Participation coeff: top_meta=0.432 vs others=0.409
#
# ================================================================================
# Pat_07  (116 channels, 7 epileptic, 119 anatomy labels)
# ================================================================================
#
#   rsPre/delta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       A1      A  0.000  EPI    32.30 Wm,90.0,ctx-lh-parsopercularis,10.0,PTD,
#       2      U12      U  0.000         34.02                      Unk,100.0,PTD, 1.00
#       3      U11      U  0.000         32.98 Unk,64.0,ctx-lh-rostralmiddlefrontal,36.
#       4      U10      U  0.000         35.35 ctx-lh-rostralmiddlefrontal,76.0,Unk,12.
#       5       F6      F  0.000         35.23 Wm,73.0,ctx-lh-rostralmiddlefrontal,27.0
#       6       F5      F  0.000         41.04                      Wm,100.0,PTD, -1.00
#       7       F4      F  0.000         40.95                      Wm,100.0,PTD, -1.00
#       8       F3      F  0.000         38.82 Wm,60.0,ctx-lh-superiorfrontal,37.0,ctx-
#       9       F2      F  0.000         33.89 ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-
#      10       F1      F  0.000         27.23 ctx-lh-superiorfrontal,71.0,ctx-lh-cauda
#      11      A10      A  0.000         34.62 Unk,91.0,ctx-lh-rostralmiddlefrontal,9.0
#      12       A9      A  0.000         29.51 ctx-lh-rostralmiddlefrontal,63.0,Unk,28.
#      13       X4      X  0.000         24.47 Wm,69.0,ctx-lh-precentral,15.0,ctx-lh-ca
#      14       X3      X  0.000         31.40 Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,c
#      15       X2      X  0.000         39.07 Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-l
#     Probe boundary contacts (first/last): 3/15
#     Probes represented: {'A': 3, 'U': 3, 'F': 6, 'X': 3}
#     Community boundary nodes: 15/15 (n*=7)
#     Participation coeff: top_meta=0.415 vs others=0.435
#
#   rsPre/theta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       A1      A  0.571  EPI    29.32 Wm,90.0,ctx-lh-parsopercularis,10.0,PTD,
#       2       A2      A  0.571  EPI    34.66 Wm,65.0,ctx-lh-rostralmiddlefrontal,18.0
#       3       Y1      Y  0.429         33.28 Wm,73.0,ctx-lh-parsopercularis,26.0,ctx-
#       4       M8      M  0.429         33.84 ctx-lh-rostralmiddlefrontal,59.0,Unk,41.
#       5       L2      L  0.429         35.68 Wm,69.0,ctx-lh-parsopercularis,29.0,ctx-
#       6       F8      F  0.429         21.75 ctx-lh-rostralmiddlefrontal,68.0,Unk,28.
#       7       X4      X  0.429         22.01 Wm,69.0,ctx-lh-precentral,15.0,ctx-lh-ca
#       8       L1      L  0.286         40.46 Wm,70.0,ctx-lh-parsopercularis,28.0,WM-h
#       9       F2      F  0.286         23.77 ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-
#      10       I7      I  0.286         31.63 ctx-lh-rostralmiddlefrontal,63.0,Wm,21.0
#      11       X3      X  0.286         31.37 Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,c
#      12       X5      X  0.286         21.55 Wm,72.0,ctx-lh-precentral,23.0,Unk,5.0,P
#      13       X6      X  0.286         23.76 Wm,38.0,ctx-lh-precentral,36.0,Unk,26.0,
#      14       F1      F  0.286         21.15 ctx-lh-superiorfrontal,71.0,ctx-lh-cauda
#      15       A9      A  0.286         34.59 ctx-lh-rostralmiddlefrontal,63.0,Unk,28.
#     Probe boundary contacts (first/last): 5/15
#     Probes represented: {'A': 3, 'Y': 1, 'M': 1, 'L': 2, 'F': 3, 'X': 4, 'I': 1}
#     Community boundary nodes: 14/15 (n*=3)
#     Participation coeff: top_meta=0.215 vs others=0.222
#
#   rsPre/alpha -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       A1      A  1.000  EPI    21.26 Wm,90.0,ctx-lh-parsopercularis,10.0,PTD,
#       2      U12      U  1.000         24.67                      Unk,100.0,PTD, 1.00
#       3      U11      U  1.000         22.01 Unk,64.0,ctx-lh-rostralmiddlefrontal,36.
#       4      U10      U  1.000         21.59 ctx-lh-rostralmiddlefrontal,76.0,Unk,12.
#       5       F6      F  1.000         22.74 Wm,73.0,ctx-lh-rostralmiddlefrontal,27.0
#       6       F5      F  1.000         25.63                      Wm,100.0,PTD, -1.00
#       7       F4      F  1.000         25.00                      Wm,100.0,PTD, -1.00
#       8       F3      F  1.000         21.85 Wm,60.0,ctx-lh-superiorfrontal,37.0,ctx-
#       9       F2      F  1.000         17.13 ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-
#      10       F1      F  1.000         14.79 ctx-lh-superiorfrontal,71.0,ctx-lh-cauda
#      11      A10      A  1.000         20.99 Unk,91.0,ctx-lh-rostralmiddlefrontal,9.0
#      12       A9      A  1.000         19.98 ctx-lh-rostralmiddlefrontal,63.0,Unk,28.
#      13       X4      X  1.000          8.77 Wm,69.0,ctx-lh-precentral,15.0,ctx-lh-ca
#      14       X3      X  1.000         17.44 Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,c
#      15       X2      X  1.000         21.91 Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-l
#     Probe boundary contacts (first/last): 3/15
#     Probes represented: {'A': 3, 'U': 3, 'F': 6, 'X': 3}
#     Community boundary nodes: 15/15 (n*=5)
#     Participation coeff: top_meta=0.589 vs others=0.580
#
#   rsPre/beta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1      Y10      Y  0.750         32.38                      Unk,100.0,PTD, 1.00
#       2       I1      I  0.750         30.94 Wm,89.0,ctx-lh-parstriangularis,11.0,PTD
#       3      J10      J  0.750         32.64                      Unk,100.0,PTD, 1.00
#       4      P16      P  0.750         18.64 Unk,63.0,ctx-lh-precentral,37.0,Wm,1.0,P
#       5       L2      L  0.750         21.13 Wm,69.0,ctx-lh-parsopercularis,29.0,ctx-
#       6      P17      P  0.750         26.51 Unk,99.0,ctx-lh-precentral,1.0,PTD, 1.00
#       7      P18      P  0.750         30.94                      Unk,100.0,PTD, 1.00
#       8       L3      L  0.750         20.41 ctx-lh-rostralmiddlefrontal,60.0,Wm,39.0
#       9       M8      M  0.750         19.34 ctx-lh-rostralmiddlefrontal,59.0,Unk,41.
#      10       L4      L  0.750         14.87 ctx-lh-rostralmiddlefrontal,73.0,Unk,19.
#      11       F2      F  0.500         16.26 ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-
#      12       X2      X  0.500         18.16 Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-l
#      13       J9      J  0.500         24.23 Unk,78.0,ctx-lh-precentral,20.0,Wm,2.0,P
#      14       X3      X  0.500         12.32 Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,c
#      15       X6      X  0.500          7.25 Wm,38.0,ctx-lh-precentral,36.0,Unk,26.0,
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'Y': 1, 'I': 1, 'J': 2, 'P': 3, 'L': 3, 'M': 1, 'F': 1, 'X': 3}
#     Community boundary nodes: 15/15 (n*=3)
#     Participation coeff: top_meta=0.253 vs others=0.263
#
# ================================================================================
# Pat_08  (120 channels, 9 epileptic, 214 anatomy labels)
# ================================================================================
#
#   rsPre/delta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       R2      R  0.000         28.08      ctx-lh-insula,94.0,Wm,6.0,PTD, 0.89
#       2       R1      R  0.000         37.44 Wm,67.0,ctx-lh-insula,28.0,ctx-lh-latera
#       3      P16      P  0.000         17.46 ctx-lh-supramarginal,43.0,Wm,41.0,Unk,15
#       4      P15      P  0.000         16.56 ctx-lh-supramarginal,50.0,Wm,30.0,Unk,20
#       5      P14      P  0.000         16.30 Wm,60.0,ctx-lh-supramarginal,37.0,Unk,3.
#       6      P13      P  0.000         16.37 Wm,88.0,ctx-lh-supramarginal,12.0,PTD, -
#       7      P12      P  0.000         15.09 Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0
#       8      P11      P  0.000         12.09 Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0
#       9       F4      F  0.000         20.68  Wm,55.0,ctx-lh-fusiform,45.0,PTD, -0.11
#      10       F3      F  0.000         16.91 ctx-lh-fusiform,72.0,Wm,27.0,ctx-lh-para
#      11       F2      F  0.000         15.61 ctx-lh-fusiform,81.0,Unk,9.0,Cerebellum-
#      12       F1      F  0.000         54.11 Cerebellum-Cortex,82.0,Unk,14.0,ctx-lh-f
#      13      D12      D  0.000         21.70 ctx-lh-middletemporal,85.0,Unk,11.0,Wm,5
#      14      D11      D  0.000         41.86 ctx-lh-middletemporal,44.0,ctx-lh-inferi
#      15      D10      D  0.000         30.75 ctx-lh-inferiortemporal,64.0,Unk,15.0,ct
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'R': 2, 'P': 6, 'F': 4, 'D': 3}
#     Community boundary nodes: 10/15 (n*=3)
#     Participation coeff: top_meta=0.343 vs others=0.208
#
#   rsPre/theta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1      R10      R  1.000         61.64 Unk,92.0,ctx-lh-parstriangularis,8.0,PTD
#       2       S4      S  1.000         38.62 Unk,54.0,ctx-lh-postcentral,41.0,ctx-lh-
#       3       T4      T  1.000  EPI    42.14 ctx-lh-superiortemporal,57.0,Wm,43.0,PTD
#       4       T5      T  1.000  EPI    49.46 ctx-lh-superiortemporal,63.0,Wm,30.0,Unk
#       5       U3      U  1.000         58.95 ctx-lh-superiortemporal,66.0,Wm,24.0,Unk
#       6       U4      U  1.000         53.92 ctx-lh-superiortemporal,51.0,Wm,49.0,PTD
#       7       U6      U  1.000         46.48 ctx-lh-middletemporal,65.0,Wm,20.0,Unk,1
#       8       U7      U  1.000         36.46 ctx-lh-middletemporal,56.0,Wm,44.0,PTD,
#       9      A11      A  1.000         46.56 ctx-lh-middletemporal,54.0,Wm,43.0,Unk,3
#      10       W4      W  1.000  EPI    47.14 Wm,55.0,ctx-lh-superiortemporal,42.0,Unk
#      11       W5      W  1.000  EPI    52.54 Wm,74.0,ctx-lh-superiortemporal,25.0,Unk
#      12       W6      W  1.000  EPI    43.60  Wm,69.0,ctx-lh-bankssts,31.0,PTD, -0.38
#      13       W7      W  1.000  EPI    38.62 ctx-lh-bankssts,69.0,Wm,25.0,Unk,6.0,PTD
#      14       W8      W  1.000  EPI    43.68 ctx-lh-bankssts,62.0,Wm,37.0,Unk,1.0,PTD
#      15       W9      W  1.000  EPI    54.19 ctx-lh-bankssts,78.0,Wm,16.0,Unk,6.0,PTD
#     Probe boundary contacts (first/last): 1/15
#     Probes represented: {'R': 1, 'S': 1, 'T': 2, 'U': 4, 'A': 1, 'W': 6}
#     Community boundary nodes: 1/15 (n*=4)
#     Participation coeff: top_meta=0.055 vs others=0.097
#
#   rsPre/alpha -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       R2      R  0.000         16.66      ctx-lh-insula,94.0,Wm,6.0,PTD, 0.89
#       2       R1      R  0.000         24.56 Wm,67.0,ctx-lh-insula,28.0,ctx-lh-latera
#       3      P16      P  0.000         19.89 ctx-lh-supramarginal,43.0,Wm,41.0,Unk,15
#       4      P15      P  0.000         18.79 ctx-lh-supramarginal,50.0,Wm,30.0,Unk,20
#       5      P14      P  0.000         18.36 Wm,60.0,ctx-lh-supramarginal,37.0,Unk,3.
#       6      P13      P  0.000         17.79 Wm,88.0,ctx-lh-supramarginal,12.0,PTD, -
#       7      P12      P  0.000         16.66 Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0
#       8      P11      P  0.000         14.03 Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0
#       9       F4      F  0.000         17.46  Wm,55.0,ctx-lh-fusiform,45.0,PTD, -0.11
#      10       F3      F  0.000         12.16 ctx-lh-fusiform,72.0,Wm,27.0,ctx-lh-para
#      11       F2      F  0.000         16.96 ctx-lh-fusiform,81.0,Unk,9.0,Cerebellum-
#      12       F1      F  0.000         31.91 Cerebellum-Cortex,82.0,Unk,14.0,ctx-lh-f
#      13      D12      D  0.000         26.86 ctx-lh-middletemporal,85.0,Unk,11.0,Wm,5
#      14      D11      D  0.000         26.88 ctx-lh-middletemporal,44.0,ctx-lh-inferi
#      15      D10      D  0.000         22.47 ctx-lh-inferiortemporal,64.0,Unk,15.0,ct
#     Probe boundary contacts (first/last): 2/15
#     Probes represented: {'R': 2, 'P': 6, 'F': 4, 'D': 3}
#     Community boundary nodes: 6/15 (n*=4)
#     Participation coeff: top_meta=0.228 vs others=0.145
#
#   rsPre/beta -- Top 15 metastable nodes:
#       #    label  probe     mu  epi strength                                  anatomy
#       1       A1      A  0.714         23.90               Unk,96.0,Amy,4.0,PTD, 1.00
#       2       F1      F  0.571         16.43 Cerebellum-Cortex,82.0,Unk,14.0,ctx-lh-f
#       3       C6      C  0.571         19.00 Wm,50.0,Hip,28.0,Inf-Lat-Vent,20.0,ctx-l
#       4      D12      D  0.571         12.91 ctx-lh-middletemporal,85.0,Unk,11.0,Wm,5
#       5       D3      D  0.429         12.89 Wm,65.0,ctx-lh-parahippocampal,26.0,Hip,
#       6       D1      D  0.429         15.54 Unk,64.0,ctx-lh-parahippocampal,26.0,ctx
#       7       C4      C  0.429          7.49               Hip,69.0,Wm,31.0,PTD, 0.38
#       8       C5      C  0.429          8.20 Hip,65.0,Wm,34.0,Inf-Lat-Vent,1.0,PTD, 0
#       9       D2      D  0.429         11.49 ctx-lh-parahippocampal,48.0,Wm,36.0,ctx-
#      10       C7      C  0.429         27.64      Wm,99.0,Inf-Lat-Vent,1.0,PTD, -0.98
#      11       C2      C  0.429         12.86 Wm,67.0,Hip,29.0,ctx-lh-parahippocampal,
#      12       D6      D  0.429         13.14 ctx-lh-fusiform,58.0,Wm,24.0,Unk,10.0,ct
#      13       C1      C  0.429         14.34 Unk,58.0,ctx-lh-parahippocampal,28.0,Cer
#      14       B5      B  0.429         13.97 Wm,45.0,ctx-lh-entorhinal,30.0,Hip,20.0,
#      15       B6      B  0.429         20.53 Wm,49.0,ctx-lh-fusiform,36.0,Inf-Lat-Ven
#     Probe boundary contacts (first/last): 4/15
#     Probes represented: {'A': 1, 'F': 1, 'C': 6, 'D': 5, 'B': 2}
#     Community boundary nodes: 0/15 (n*=3)
#     Participation coeff: top_meta=0.042 vs others=0.109
#
#
# Per-patient analysis complete.

# %% [markdown]
# ## Cross-patient aggregate statistics
#
# Now pool all top-metastable nodes across patients and bands to find patterns.

# %%
df = pd.DataFrame(all_rows)
print(f"Total rows: {len(df)}")
print(f"Patients: {df['patient'].nunique()}")
print(f"Bands: {df['band'].unique().tolist()}")

# ── 1. Epileptic fraction among top metastable nodes ──
n_epi = df['is_epi'].sum()
n_total = len(df)
print(f"\n--- Epileptic nodes among top-{TOP_K} metastable ---")
print(f"  {n_epi}/{n_total} = {100 * n_epi / n_total:.1f}%")

# Compare to baseline: what fraction of ALL nodes are epileptic?
baseline_epi_fracs = []
for patient in patients:
    epi_set = set(load_epileptic_nodes(patient))
    ch = load_ch(patient)
    frac = sum(1 for l in ch if l in epi_set) / len(ch)
    baseline_epi_fracs.append(frac)
    print(f"  {patient} baseline epileptic fraction: {100 * frac:.1f}%")
print(f"  Mean baseline: {100 * np.mean(baseline_epi_fracs):.1f}%")

# ── 2. Anatomy distribution ──
print(f"\n--- Anatomical regions (Desikan-Killiany) in top metastable ---")
anat_counts = df[df['anatomy'] != '?']['anatomy'].value_counts()
print(anat_counts.head(20).to_string())
print(f"\n  Unique regions: {df[df['anatomy'] != '?']['anatomy'].nunique()}")
print(f"  Missing anatomy ('?'): {(df['anatomy'] == '?').sum()}/{n_total}")

# ── 3. Probe boundary fraction (need to recompute) ──
print(f"\n--- Probe boundary analysis ---")
boundary_counts_per_band = {}
for band in bands:
    sub = df[df['band'] == band]
    # We stored labels and probes; check if label is first or last on its probe
    # within each patient
    boundary = 0
    for _, row in sub.iterrows():
        ch = load_ch(row['patient'])
        probe = row['probe']
        probe_contacts = sorted([c for c in ch if get_probe(c) == probe])
        if row['label'] == probe_contacts[0] or row['label'] == probe_contacts[-1]:
            boundary += 1
    boundary_counts_per_band[band] = (boundary, len(sub))
    print(f"  {band}: {boundary}/{len(sub)} = {100 * boundary / len(sub):.1f}% "
          f"are probe boundary contacts")

total_boundary = sum(v[0] for v in boundary_counts_per_band.values())
total_n = sum(v[1] for v in boundary_counts_per_band.values())
print(f"  TOTAL: {total_boundary}/{total_n} = {100 * total_boundary / total_n:.1f}%")

# ── 4. Per-band epileptic breakdown ──
print(f"\n--- Epileptic fraction per band ---")
for band in bands:
    sub = df[df['band'] == band]
    n_e = sub['is_epi'].sum()
    print(f"  {band}: {n_e}/{len(sub)} = {100 * n_e / len(sub):.1f}%")
# Out:
# Total rows: 300
# Patients: 5
# Bands: ['delta', 'theta', 'alpha', 'beta']
#
# --- Epileptic nodes among top-15 metastable ---
#   19/300 = 6.3%
#   Pat_02 baseline epileptic fraction: 12.0%
#   Pat_03 baseline epileptic fraction: 4.9%
#   Pat_05 baseline epileptic fraction: 11.9%
#   Pat_07 baseline epileptic fraction: 6.0%
#   Pat_08 baseline epileptic fraction: 7.5%
#   Mean baseline: 8.5%
#
# --- Anatomical regions (Desikan-Killiany) in top metastable ---
# anatomy
# Unk,100.0,PTD, 1.00                                                                                            8
# Wm,100.0,PTD, -1.00                                                                                            5
# Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0.98                                                                    4
# Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD, -0.69                                                                4
# ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-lh-caudalanteriorcingulate,10.0,Unk,2.0,PTD, 0.56                      4
# Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,ctx-lh-precentral,3.0,PTD, -0.77                                        4
# Wm,90.0,ctx-lh-parsopercularis,10.0,PTD, -0.80                                                                 3
# ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,Unk,15.0,PTD, 0.30                                                     3
# ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,Unk,8.0,PTD, 0.09                                                      3
# Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-lh-rostralmiddlefrontal,2.0,PTD, -0.79                                  3
# ctx-lh-middletemporal,85.0,Unk,11.0,Wm,5.0,PTD, 0.90                                                           3
# Cerebellum-Cortex,82.0,Unk,14.0,ctx-lh-fusiform,3.0,ctx-lh-parahippocampal,1.0,PTD, 1.00                       3
# ctx-lh-precuneus,77.0,Unk,14.0,ctx-lh-cuneus,6.0,Wm,3.0,PTD, 0.93                                              3
# ctx-lh-lateralorbitofrontal,65.0,Wm,35.0,PTD, 0.30                                                             3
# ctx-lh-lateralorbitofrontal,50.0,Wm,48.0,ctx-lh-medialorbitofrontal,2.0,PTD, 0.04                              3
# ctx-lh-lateralorbitofrontal,45.0,ctx-lh-medialorbitofrontal,34.0,Wm,20.0,Unk,2.0,PTD, 0.61                     3
# ctx-lh-rostralmiddlefrontal,55.0,Wm,37.0,Unk,7.0,ctx-lh-superiorfrontal,2.0,PTD, 0.27                          3
# Wm,69.0,ctx-lh-precentral,15.0,ctx-lh-caudalmiddlefrontal,9.0,Unk,4.0,ctx-lh-parsopercularis,2.0,PTD, -0.38    3
# ctx-rh-medialorbitofrontal,52.0,ctx-rh-rostralanteriorcingulate,28.0,Unk,14.0,Wm,6.0,PTD, 0.89                 3
# ctx-lh-rostralmiddlefrontal,63.0,Unk,28.0,Wm,8.0,PTD, 0.84                                                     3
#
#   Unique regions: 192
#   Missing anatomy ('?'): 0/300
#
# --- Probe boundary analysis ---
#   delta: 14/75 = 18.7% are probe boundary contacts
#   theta: 19/75 = 25.3% are probe boundary contacts
#   alpha: 15/75 = 20.0% are probe boundary contacts
#   beta: 14/75 = 18.7% are probe boundary contacts
#   TOTAL: 62/300 = 20.7%
#
# --- Epileptic fraction per band ---
#   delta: 6/75 = 8.0%
#   theta: 10/75 = 13.3%
#   alpha: 3/75 = 4.0%
#   beta: 0/75 = 0.0%

# %% [markdown]
# ## Parse dominant cortical region from probabilistic anatomy strings
#
# The Excel column 5 contains probabilistic tissue assignments like
# `ctx-lh-superiorfrontal,66.0,Wm,22.0,...`. We extract the **dominant cortical region** (ignoring Wm/Unk) for meaningful anatomical grouping.

# %%
def parse_dominant_region(anat_string):
    """Extract the dominant cortical region from a probabilistic anatomy string.
    
    E.g. 'ctx-lh-superiorfrontal,66.0,Wm,22.0,Unk,12.0,PTD, 0.56'
    -> 'superiorfrontal (L)' (the dominant cortical region)
    
    Returns 'white_matter' if Wm dominates, 'unknown' if Unk dominates,
    or the cortical/subcortical label.
    """
    if not anat_string or anat_string == '?':
        return 'no_data'
    
    # Parse pairs: (tissue_label, percentage)
    parts = anat_string.replace('PTD,', '').strip().split(',')
    pairs = []
    i = 0
    while i < len(parts) - 1:
        label = parts[i].strip()
        try:
            pct = float(parts[i + 1].strip())
            pairs.append((label, pct))
            i += 2
        except ValueError:
            i += 1
    
    if not pairs:
        return 'unparseable'
    
    cortical = [(lbl, pct) for lbl, pct in pairs if lbl.startswith('ctx-')]
    subcortical = [(lbl, pct) for lbl, pct in pairs 
                   if not lbl.startswith('ctx-') and lbl not in ('Wm', 'Unk')]
    wm_pct = sum(pct for lbl, pct in pairs if lbl == 'Wm')
    unk_pct = sum(pct for lbl, pct in pairs if lbl == 'Unk')
    
    if cortical:
        best = max(cortical, key=lambda x: x[1])
        short = best[0].split('-', 2)[-1] if '-' in best[0] else best[0]
        hemi = 'L' if '-lh-' in best[0] else ('R' if '-rh-' in best[0] else '')
        return f"{short} ({hemi})" if hemi else short
    elif subcortical:
        best = max(subcortical, key=lambda x: x[1])
        return best[0]
    elif wm_pct >= unk_pct:
        return 'white_matter'
    else:
        return 'unknown'


def broad_category(region):
    """Map DK regions to broad lobar categories."""
    if region in ('white_matter', 'unknown', 'no_data', 'unparseable'):
        return region
    frontal = ['superiorfrontal', 'caudalmiddlefrontal', 'rostralmiddlefrontal',
               'parsopercularis', 'parsorbitalis', 'parstriangularis',
               'lateralorbitofrontal', 'medialorbitofrontal', 'frontalpole',
               'caudalanteriorcingulate', 'rostralanteriorcingulate', 'precentral']
    temporal = ['superiortemporal', 'middletemporal', 'inferiortemporal',
                'transversetemporal', 'bankssts', 'fusiform', 'entorhinal',
                'temporalpole', 'parahippocampal']
    parietal = ['superiorparietal', 'inferiorparietal', 'supramarginal',
                'postcentral', 'precuneus']
    occipital = ['lateraloccipital', 'lingual', 'cuneus', 'pericalcarine']
    limbic = ['posteriorcingulate', 'isthmuscingulate', 'insula']
    
    base = region.split(' (')[0]
    if base in frontal:
        return 'frontal'
    elif base in temporal:
        return 'temporal'
    elif base in parietal:
        return 'parietal'
    elif base in occipital:
        return 'occipital'
    elif base in limbic:
        return 'limbic'
    elif 'Cerebellum' in region:
        return 'cerebellum'
    else:
        return 'other'


# Apply to the dataframe
df['region'] = df['anatomy'].apply(parse_dominant_region)
df['broad_region'] = df['region'].apply(broad_category)

print("Dominant cortical region distribution in top-metastable nodes:\n")
region_counts = df['region'].value_counts()
print(region_counts.to_string())
print(f"\nTotal unique regions: {df['region'].nunique()}")

print("\n\nBroad region distribution:")
broad_counts = df['broad_region'].value_counts()
print(broad_counts.to_string())

# Per-patient enrichment
print("\n\nPer-patient: broad region enrichment (meta vs implant)")
for patient in patients:
    anatomy = load_implant_anatomy(patient)
    ch_labels = load_ch(patient)
    
    all_regions = [broad_category(parse_dominant_region(anatomy.get(l, '?'))) 
                   for l in ch_labels]
    all_counts = Counter(all_regions)
    total_all = len(ch_labels)
    
    sub = df[df['patient'] == patient]
    meta_counts = Counter(sub['broad_region'].values)
    total_meta = len(sub)
    
    print(f"\n  {patient} ({total_all} ch, {total_meta} meta entries)")
    print(f"    {'Category':<15s} {'Implant%':>9s} {'Meta%':>9s} {'Ratio':>7s}")
    all_cats = sorted(set(list(all_counts.keys()) + list(meta_counts.keys())))
    for cat in all_cats:
        a_frac = all_counts.get(cat, 0) / total_all
        m_frac = meta_counts.get(cat, 0) / total_meta
        ratio = m_frac / a_frac if a_frac > 0 else float('inf')
        marker = ' **' if ratio > 1.5 else (' --' if ratio < 0.5 else '')
        print(f"    {cat:<15s} {100*a_frac:8.1f}% {100*m_frac:8.1f}% "
              f"{ratio:6.2f}x{marker}")
# Out:
# Dominant cortical region distribution in top-metastable nodes:
#
# region
# fusiform (L)                    29
# rostralmiddlefrontal (L)        27
# middletemporal (L)              23
# inferiortemporal (L)            23
# medialorbitofrontal (R)         16
# superiorfrontal (L)             13
# supramarginal (L)               12
# superiortemporal (L)            12
# precuneus (L)                   11
# caudalmiddlefrontal (L)         11
# superiorfrontal (R)             10
# parsopercularis (L)             10
# precentral (L)                   9
# lateralorbitofrontal (L)         9
# rostralmiddlefrontal (R)         9
# parahippocampal (L)              9
# bankssts (L)                     8
# unknown                          8
# Hip                              6
# cuneus (L)                       6
# white_matter                     5
# entorhinal (L)                   4
# insula (L)                       4
# rostralanteriorcingulate (R)     4
# medialorbitofrontal (L)          3
# parsorbitalis (L)                3
# lateraloccipital (L)             3
# inferiorparietal (L)             3
# lingual (L)                      2
# parstriangularis (L)             2
# pericalcarine (L)                1
# isthmuscingulate (L)             1
# lateralorbitofrontal (R)         1
# postcentral (L)                  1
# Amy                              1
# Inf-Lat-Vent                     1
#
# Total unique regions: 36
#
#
# Broad region distribution:
# broad_region
# frontal         127
# temporal        108
# parietal         27
# occipital        12
# unknown           8
# other             8
# white_matter      5
# limbic            5
#
#
# Per-patient: broad region enrichment (meta vs implant)
#
#   Pat_02 (117 ch, 60 meta entries)
#     Category         Implant%     Meta%   Ratio
#     frontal              9.4%     25.0%   2.66x **
#     limbic               2.6%      1.7%   0.65x
#     occipital           11.1%      1.7%   0.15x --
#     other                0.9%      0.0%   0.00x --
#     parietal             7.7%      0.0%   0.00x --
#     temporal            64.1%     65.0%   1.01x
#     unknown              0.9%      5.0%   5.85x **
#     white_matter         3.4%      1.7%   0.49x --
#
#   Pat_03 (122 ch, 60 meta entries)
#     Category         Implant%     Meta%   Ratio
#     occipital           20.5%     18.3%   0.89x
#     other                7.4%      6.7%   0.90x
#     parietal            18.9%     23.3%   1.24x
#     temporal            53.3%     51.7%   0.97x
#
#   Pat_05 (118 ch, 60 meta entries)
#     Category         Implant%     Meta%   Ratio
#     frontal             97.5%    100.0%   1.03x
#     no_data              0.8%      0.0%   0.00x --
#     white_matter         1.7%      0.0%   0.00x --
#
#   Pat_07 (116 ch, 60 meta entries)
#     Category         Implant%     Meta%   Ratio
#     frontal             86.2%     85.0%   0.99x
#     limbic               0.9%      0.0%   0.00x --
#     no_data              2.6%      0.0%   0.00x --
#     unknown              6.9%      8.3%   1.21x
#     white_matter         3.4%      6.7%   1.93x **
#
#   Pat_08 (120 ch, 60 meta entries)
#     Category         Implant%     Meta%   Ratio
#     frontal              5.8%      1.7%   0.29x --
#     limbic              10.8%      6.7%   0.62x
#     other                6.7%      6.7%   1.00x
#     parietal            14.2%     21.7%   1.53x **
#     temporal            59.2%     63.3%   1.07x
#     unknown              0.8%      0.0%   0.00x --
#     white_matter         2.5%      0.0%   0.00x --

# %% [markdown]
# ## Anatomical enrichment analysis
#
# Are certain brain regions over-represented among metastable nodes compared to the implant as a whole?

# %%
# For each patient, compare anatomical distribution in top-metastable vs ALL nodes
print("=== Anatomical enrichment: top-metastable vs whole implant ===\n")

for patient in patients:
    anatomy = load_implant_anatomy(patient)
    ch = load_ch(patient)
    
    # All-node anatomy distribution
    all_anat = [anatomy.get(l, '?') for l in ch]
    all_anat_counts = Counter(a for a in all_anat if a != '?')
    total_with_anat = sum(all_anat_counts.values())
    
    if total_with_anat == 0:
        print(f"{patient}: no anatomy data available\n")
        continue
    
    # Top-metastable anatomy (across all bands)
    sub = df[(df['patient'] == patient) & (df['anatomy'] != '?')]
    if len(sub) == 0:
        print(f"{patient}: no anatomy matches for top metastable nodes\n")
        continue
    
    meta_anat_counts = Counter(sub['anatomy'].values)
    
    print(f"{patient}  (total channels with anatomy: {total_with_anat})")
    print(f"  {'Region':<35s} {'All%':>6s} {'Meta%':>6s} {'Enrichment':>10s}")
    
    # Get all regions that appear in either
    all_regions = set(all_anat_counts.keys()) | set(meta_anat_counts.keys())
    enrichment_data = []
    for region in all_regions:
        all_frac = all_anat_counts.get(region, 0) / total_with_anat
        meta_frac = meta_anat_counts.get(region, 0) / len(sub)
        enrichment = meta_frac / all_frac if all_frac > 0 else float('inf')
        enrichment_data.append((region, all_frac, meta_frac, enrichment))
    
    # Sort by enrichment
    enrichment_data.sort(key=lambda x: x[3], reverse=True)
    for region, all_frac, meta_frac, enrichment in enrichment_data:
        if meta_frac > 0:  # only show regions present in metastable set
            marker = ' ***' if enrichment > 2.0 else (' **' if enrichment > 1.5 else '')
            print(f"  {region:<35s} {100*all_frac:5.1f}% {100*meta_frac:5.1f}% "
                  f"{enrichment:9.2f}x{marker}")
    
    # Regions in implant but NOT in metastable set
    depleted = [r for r, af, mf, e in enrichment_data if mf == 0 and af > 0.03]
    if depleted:
        print(f"  Depleted (>3% of implant, 0% in meta): {depleted}")
    print()
# Out:
# === Anatomical enrichment: top-metastable vs whole implant ===
#
# Pat_02  (total channels with anatomy: 117)
#   Region                                All%  Meta% Enrichment
#   Unk,100.0,PTD, 1.00                   0.9%   5.0%      5.85x ***
#   ctx-lh-lateralorbitofrontal,50.0,Wm,48.0,ctx-lh-medialorbitofrontal,2.0,PTD, 0.04   0.9%   5.0%      5.85x ***
#   ctx-lh-lateralorbitofrontal,45.0,ctx-lh-medialorbitofrontal,34.0,Wm,20.0,Unk,2.0,PTD, 0.61   0.9%   5.0%      5.85x ***
#   ctx-lh-lateralorbitofrontal,65.0,Wm,35.0,PTD, 0.30   0.9%   5.0%      5.85x ***
#   ctx-lh-fusiform,67.0,Wm,33.0,PTD, 0.33   0.9%   3.3%      3.90x ***
#   Unk,67.0,ctx-lh-middletemporal,33.0,PTD, 1.00   0.9%   3.3%      3.90x ***
#   ctx-lh-bankssts,62.0,Unk,37.0,Wm,1.0,PTD, 0.98   0.9%   3.3%      3.90x ***
#   Cerebellum-Cortex,30.0,ctx-lh-parahippocampal,26.0,ctx-lh-lingual,19.0,Unk,15.0,ctx-lh-fusiform,10.0,PTD, 1.00   0.9%   3.3%      3.90x ***
#   ctx-lh-medialorbitofrontal,79.0,Wm,14.0,Unk,7.0,PTD, 0.72   0.9%   3.3%      3.90x ***
#   Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD, -0.69   0.9%   3.3%      3.90x ***
#   Wm,59.0,ctx-lh-fusiform,41.0,PTD, -0.19   0.9%   3.3%      3.90x ***
#   ctx-lh-fusiform,79.0,ctx-lh-inferiortemporal,11.0,Unk,7.0,Wm,3.0,PTD, 0.93   0.9%   3.3%      3.90x ***
#   Unk,86.0,ctx-lh-parsorbitalis,14.0,PTD, 1.00   0.9%   3.3%      3.90x ***
#   ctx-lh-superiortemporal,55.0,Wm,44.0,Unk,1.0,PTD, 0.12   0.9%   3.3%      3.90x ***
#   ctx-lh-superiortemporal,49.0,ctx-lh-middletemporal,38.0,Unk,12.0,Wm,1.0,PTD, 0.98   0.9%   3.3%      3.90x ***
#   ctx-lh-inferiortemporal,72.0,Wm,21.0,Unk,7.0,PTD, 0.58   0.9%   1.7%      1.95x **
#   Unk,40.0,ctx-lh-parsorbitalis,34.0,ctx-lh-lateralorbitofrontal,26.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   Wm,57.0,Hip,23.0,ctx-lh-parahippocampal,20.0,ctx-lh-fusiform,1.0,PTD, -0.14   0.9%   1.7%      1.95x **
#   Unk,72.0,ctx-lh-middletemporal,28.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   ctx-lh-fusiform,76.0,Unk,11.0,ctx-lh-lingual,8.0,ctx-lh-parahippocampal,4.0,Wm,2.0,PTD, 0.97   0.9%   1.7%      1.95x **
#   Unk,51.0,ctx-lh-middletemporal,45.0,ctx-lh-inferiortemporal,4.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   Wm,54.0,ctx-lh-inferiortemporal,29.0,ctx-lh-fusiform,11.0,Unk,6.0,PTD, -0.09   0.9%   1.7%      1.95x **
#   ctx-lh-superiortemporal,79.0,ctx-lh-middletemporal,9.0,Wm,3.0,PTD, 0.93   0.9%   1.7%      1.95x **
#   ctx-lh-middletemporal,50.0,ctx-lh-superiortemporal,1.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   ctx-lh-inferiortemporal,57.0,Wm,43.0,PTD, 0.14   0.9%   1.7%      1.95x **
#   ctx-lh-superiortemporal,68.0,Wm,28.0,ctx-lh-middletemporal,2.0,PTD, 0.43   0.9%   1.7%      1.95x **
#   ctx-lh-bankssts,76.0,Unk,24.0,Wm,1.0,PTD, 0.98   0.9%   1.7%      1.95x **
#   Wm,72.0,ctx-lh-fusiform,16.0,Amy,6.0,PTD, -0.45   0.9%   1.7%      1.95x **
#   ctx-lh-bankssts,52.0,Wm,48.0,PTD, 0.04   0.9%   1.7%      1.95x **
#   Wm,46.0,ctx-lh-inferiortemporal,44.0,ctx-lh-middletemporal,10.0,Unk,1.0,PTD, 0.09   0.9%   1.7%      1.95x **
#   ctx-lh-fusiform,45.0,Unk,39.0,ctx-lh-inferiortemporal,16.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   ctx-lh-isthmuscingulate,72.0,ctx-lh-precuneus,15.0,Wm,10.0,Unk,4.0,PTD, 0.80   0.9%   1.7%      1.95x **
#   ctx-lh-fusiform,52.0,Wm,48.0,PTD, 0.04   0.9%   1.7%      1.95x **
#   ctx-lh-fusiform,50.0,Wm,38.0,ctx-lh-inferiortemporal,8.0,Unk,3.0,PTD, 0.24   0.9%   1.7%      1.95x **
#   ctx-lh-fusiform,53.0,Wm,46.0,Unk,1.0,PTD, 0.07   0.9%   1.7%      1.95x **
#   ctx-lh-fusiform,66.0,ctx-lh-inferiortemporal,15.0,Wm,11.0,Unk,8.0,PTD, 0.77   0.9%   1.7%      1.95x **
#   ctx-lh-inferiortemporal,87.0,Unk,7.0,Wm,6.0,PTD, 0.89   0.9%   1.7%      1.95x **
#   ctx-lh-medialorbitofrontal,57.0,Wm,41.0,ctx-lh-lateralorbitofrontal,2.0,PTD, 0.19   0.9%   1.7%      1.95x **
#   Wm,59.0,ctx-lh-lateraloccipital,22.0,ctx-lh-inferiortemporal,20.0,PTD, -0.17   0.9%   1.7%      1.95x **
#   Wm,64.0,ctx-lh-inferiortemporal,28.0,ctx-lh-fusiform,7.0,PTD, -0.28   0.9%   1.7%      1.95x **
#   Wm,100.0,PTD, -1.00                   3.4%   1.7%      0.49x
#
# Pat_03  (total channels with anatomy: 122)
#   Region                                All%  Meta% Enrichment
#   ctx-lh-precuneus,77.0,Unk,14.0,ctx-lh-cuneus,6.0,Wm,3.0,PTD, 0.93   0.8%   5.0%      6.10x ***
#   ctx-lh-cuneus,60.0,ctx-lh-precuneus,25.0,Unk,11.0,Wm,4.0,PTD, 0.92   0.8%   5.0%      6.10x ***
#   ctx-lh-inferiortemporal,85.0,ctx-lh-middletemporal,7.0,Wm,6.0,Unk,2.0,PTD, 0.89   0.8%   3.3%      4.07x ***
#   Wm,65.0,ctx-lh-fusiform,34.0,ctx-lh-inferiortemporal,1.0,PTD, -0.30   0.8%   3.3%      4.07x ***
#   ctx-lh-inferiortemporal,46.0,ctx-lh-middletemporal,38.0,Unk,15.0,Wm,1.0,PTD, 0.98   0.8%   3.3%      4.07x ***
#   ctx-lh-inferiortemporal,57.0,ctx-lh-middletemporal,33.0,Unk,11.0,PTD, 1.00   0.8%   3.3%      4.07x ***
#   ctx-lh-middletemporal,68.0,ctx-lh-inferiortemporal,24.0,Wm,7.0,Unk,1.0,PTD, 0.87   0.8%   3.3%      4.07x ***
#   ctx-lh-middletemporal,92.0,Wm,8.0,PTD, 0.84   0.8%   3.3%      4.07x ***
#   ctx-lh-entorhinal,59.0,Wm,32.0,ctx-lh-fusiform,8.0,Unk,1.0,PTD, 0.37   0.8%   3.3%      4.07x ***
#   Wm,54.0,ctx-lh-inferiortemporal,34.0,ctx-lh-fusiform,11.0,PTD, -0.09   0.8%   3.3%      4.07x ***
#   Wm,51.0,ctx-lh-middletemporal,49.0,PTD, -0.02   0.8%   1.7%      2.03x ***
#   ctx-lh-precuneus,50.0,Unk,30.0,ctx-lh-cuneus,6.0,ctx-lh-pericalcarine,5.0,Wm,3.0,ctx-rh-lingual,1.0,PTD, 0.93   0.8%   1.7%      2.03x ***
#   Wm,60.0,ctx-lh-inferiortemporal,36.0,ctx-lh-fusiform,4.0,PTD, -0.20   0.8%   1.7%      2.03x ***
#   ctx-lh-inferiorparietal,52.0,Wm,40.0,Unk,8.0,PTD, 0.20   0.8%   1.7%      2.03x ***
#   Wm,50.0,ctx-lh-fusiform,46.0,ctx-lh-inferiortemporal,4.0,PTD, -0.01   0.8%   1.7%      2.03x ***
#   Wm,93.0,ctx-lh-pericalcarine,7.0,PTD, -0.87   0.8%   1.7%      2.03x ***
#   ctx-lh-inferiortemporal,66.0,Wm,33.0,Unk,2.0,PTD, 0.35   0.8%   1.7%      2.03x ***
#   ctx-lh-inferiorparietal,73.0,Wm,17.0,Unk,10.0,PTD, 0.66   0.8%   1.7%      2.03x ***
#   ctx-lh-middletemporal,76.0,Wm,24.0,PTD, 0.51   0.8%   1.7%      2.03x ***
#   ctx-lh-middletemporal,76.0,Unk,24.0,PTD, 1.00   0.8%   1.7%      2.03x ***
#   ctx-lh-cuneus,37.0,Unk,27.0,Wm,24.0,ctx-lh-pericalcarine,8.0,ctx-rh-cuneus,4.0,PTD, 0.53   0.8%   1.7%      2.03x ***
#   ctx-lh-precuneus,47.0,ctx-lh-cuneus,23.0,Unk,16.0,ctx-lh-pericalcarine,7.0,Wm,7.0,PTD, 0.87   0.8%   1.7%      2.03x ***
#   Unk,32.0,ctx-lh-precuneus,31.0,ctx-lh-cuneus,19.0,ctx-lh-pericalcarine,15.0,ctx-lh-lingual,3.0,Wm,1.0,PTD, 0.98   0.8%   1.7%      2.03x ***
#   ctx-lh-precuneus,71.0,ctx-rh-precuneus,15.0,Wm,7.0,PTD, 0.85   0.8%   1.7%      2.03x ***
#   ctx-lh-middletemporal,79.0,Wm,21.0,PTD, 0.58   0.8%   1.7%      2.03x ***
#   Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD, -0.69   1.6%   3.3%      2.03x ***
#   Hip,81.0,Wm,19.0,PTD, 0.63            0.8%   1.7%      2.03x ***
#   ctx-lh-cuneus,65.0,Wm,30.0,Unk,4.0,ctx-rh-cuneus,1.0,PTD, 0.40   0.8%   1.7%      2.03x ***
#   ctx-lh-middletemporal,87.0,Unk,13.0,PTD, 1.00   0.8%   1.7%      2.03x ***
#   Wm,78.0,ctx-lh-lateraloccipital,22.0,PTD, -0.56   0.8%   1.7%      2.03x ***
#   ctx-lh-precuneus,56.0,Wm,41.0,Unk,3.0,PTD, 0.19   0.8%   1.7%      2.03x ***
#   Wm,55.0,ctx-lh-middletemporal,45.0,PTD, -0.11   0.8%   1.7%      2.03x ***
#   Wm,85.0,ctx-lh-fusiform,7.0,ctx-lh-entorhinal,7.0,ctx-lh-inferiortemporal,1.0,PTD, -0.71   0.8%   1.7%      2.03x ***
#   Unk,37.0,ctx-lh-precuneus,22.0,ctx-lh-cuneus,19.0,ctx-lh-pericalcarine,11.0,Wm,9.0,ctx-lh-lingual,2.0,PTD, 0.82   0.8%   1.7%      2.03x ***
#   ctx-lh-fusiform,60.0,Wm,25.0,ctx-lh-lingual,12.0,Unk,2.0,PTD, 0.50   0.8%   1.7%      2.03x ***
#   ctx-lh-lingual,53.0,ctx-lh-fusiform,29.0,Wm,11.0,Unk,7.0,PTD, 0.77   0.8%   1.7%      2.03x ***
#   Wm,70.0,ctx-lh-lingual,28.0,Unk,2.0,PTD, -0.40   0.8%   1.7%      2.03x ***
#   Wm,61.0,ctx-lh-precuneus,39.0,PTD, -0.22   0.8%   1.7%      2.03x ***
#   Wm,62.0,ctx-lh-lateraloccipital,24.0,ctx-lh-inferiortemporal,13.0,ctx-lh-fusiform,2.0,PTD, -0.24   0.8%   1.7%      2.03x ***
#   ctx-lh-cuneus,60.0,Wm,40.0,PTD, 0.20   0.8%   1.7%      2.03x ***
#   Wm,59.0,ctx-lh-inferiortemporal,41.0,PTD, -0.17   0.8%   1.7%      2.03x ***
#   Hip,99.0,Wm,1.0,PTD, 0.98             0.8%   1.7%      2.03x ***
#   Hip,91.0,Thalamus-Proper,5.0,Wm,4.0,PTD, 0.92   0.8%   1.7%      2.03x ***
#   ctx-lh-inferiorparietal,60.0,Wm,33.0,Unk,7.0,PTD, 0.33   0.8%   1.7%      2.03x ***
#   ctx-lh-precuneus,84.0,Wm,15.0,Unk,2.0,PTD, 0.71   0.8%   1.7%      2.03x ***
#   ctx-lh-entorhinal,92.0,Wm,7.0,Unk,2.0,PTD, 0.87   0.8%   1.7%      2.03x ***
#   Hip,100.0,PTD, 1.00                   1.6%   1.7%      1.02x
#
# Pat_05  (total channels with anatomy: 117)
#   Region                                All%  Meta% Enrichment
#   ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,Unk,15.0,PTD, 0.30   0.9%   5.0%      5.85x ***
#   ctx-lh-rostralmiddlefrontal,55.0,Wm,37.0,Unk,7.0,ctx-lh-superiorfrontal,2.0,PTD, 0.27   0.9%   5.0%      5.85x ***
#   ctx-rh-medialorbitofrontal,52.0,ctx-rh-rostralanteriorcingulate,28.0,Unk,14.0,Wm,6.0,PTD, 0.89   0.9%   5.0%      5.85x ***
#   ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,Unk,8.0,PTD, 0.09   0.9%   5.0%      5.85x ***
#   ctx-lh-rostralmiddlefrontal,79.0,Wm,21.0,PTD, 0.58   0.9%   3.3%      3.90x ***
#   ctx-rh-superiorfrontal,49.0,Wm,46.0,Unk,6.0,PTD, 0.09   0.9%   3.3%      3.90x ***
#   ctx-rh-medialorbitofrontal,53.0,ctx-rh-rostralanteriorcingulate,35.0,Wm,12.0,PTD, 0.76   0.9%   3.3%      3.90x ***
#   ctx-rh-rostralmiddlefrontal,50.0,Wm,41.0,Unk,8.0,PTD, 0.17   0.9%   3.3%      3.90x ***
#   Wm,53.0,ctx-rh-superiorfrontal,46.0,Unk,1.0,PTD, -0.06   0.9%   3.3%      3.90x ***
#   ctx-rh-medialorbitofrontal,61.0,Wm,37.0,Unk,2.0,PTD, 0.25   0.9%   3.3%      3.90x ***
#   Wm,50.0,ctx-rh-medialorbitofrontal,50.0,PTD, -0.01   0.9%   3.3%      3.90x ***
#   Wm,68.0,ctx-lh-rostralmiddlefrontal,32.0,PTD, -0.37   0.9%   3.3%      3.90x ***
#   ctx-rh-rostralmiddlefrontal,65.0,Wm,20.0,Unk,15.0,PTD, 0.59   0.9%   3.3%      3.90x ***
#   ctx-rh-medialorbitofrontal,68.0,Unk,31.0,Wm,1.0,PTD, 0.98   0.9%   3.3%      3.90x ***
#   Wm,59.0,ctx-lh-rostralmiddlefrontal,41.0,PTD, -0.19   0.9%   3.3%      3.90x ***
#   ctx-rh-medialorbitofrontal,55.0,Wm,44.0,ctx-rh-rostralanteriorcingulate,1.0,PTD, 0.12   0.9%   3.3%      3.90x ***
#   ctx-rh-rostralanteriorcingulate,56.0,Wm,23.0,ctx-rh-medialorbitofrontal,12.0,Unk,9.0,PTD, 0.54   0.9%   3.3%      3.90x ***
#   ctx-rh-rostralanteriorcingulate,45.0,ctx-rh-medialorbitofrontal,32.0,Unk,14.0,Wm,10.0,PTD, 0.80   0.9%   3.3%      3.90x ***
#   ctx-rh-medialorbitofrontal,63.0,ctx-rh-rostralanteriorcingulate,19.0,Unk,12.0,Wm,6.0,PTD, 0.89   0.9%   3.3%      3.90x ***
#   ctx-rh-superiorfrontal,63.0,Unk,24.0,Wm,13.0,PTD, 0.74   0.9%   1.7%      1.95x **
#   Wm,54.0,ctx-rh-medialorbitofrontal,44.0,Unk,2.0,PTD, -0.09   0.9%   1.7%      1.95x **
#   ctx-rh-rostralmiddlefrontal,59.0,Wm,36.0,Unk,6.0,PTD, 0.28   0.9%   1.7%      1.95x **
#   Unk,62.0,ctx-lh-superiorfrontal,35.0,ctx-lh-rostralmiddlefrontal,3.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   ctx-rh-rostralmiddlefrontal,76.0,Unk,20.0,Wm,4.0,PTD, 0.92   0.9%   1.7%      1.95x **
#   Wm,57.0,ctx-lh-caudalmiddlefrontal,38.0,Unk,4.0,ctx-lh-precentral,1.0,PTD, -0.14   0.9%   1.7%      1.95x **
#   ctx-lh-superiorfrontal,51.0,ctx-lh-rostralmiddlefrontal,39.0,Unk,10.0,PTD, 1.00   0.9%   1.7%      1.95x **
#   ctx-rh-superiorfrontal,54.0,Wm,41.0,Unk,5.0,PTD, 0.17   0.9%   1.7%      1.95x **
#   ctx-lh-superiorfrontal,53.0,Wm,47.0,PTD, 0.06   0.9%   1.7%      1.95x **
#   ctx-rh-rostralmiddlefrontal,82.0,Wm,9.0,PTD, 0.82   0.9%   1.7%      1.95x **
#   ctx-rh-rostralmiddlefrontal,50.0,Wm,35.0,Unk,11.0,ctx-rh-superiorfrontal,4.0,PTD, 0.30   0.9%   1.7%      1.95x **
#   Wm,90.0,ctx-rh-superiorfrontal,10.0,PTD, -0.80   1.7%   3.3%      1.95x **
#   Wm,88.0,ctx-lh-superiorfrontal,12.0,PTD, -0.76   0.9%   1.7%      1.95x **
#   ctx-rh-rostralmiddlefrontal,51.0,Wm,43.0,Unk,6.0,PTD, 0.14   0.9%   1.7%      1.95x **
#   Wm,59.0,ctx-rh-superiorfrontal,34.0,Unk,7.0,PTD, -0.19   0.9%   1.7%      1.95x **
#   Wm,56.0,ctx-rh-lateralorbitofrontal,44.0,PTD, -0.12   0.9%   1.7%      1.95x **
#   ctx-rh-superiorfrontal,45.0,ctx-rh-rostralmiddlefrontal,10.0,Wm,1.0,PTD, 0.98   0.9%   1.7%      1.95x **
#
# Pat_07  (total channels with anatomy: 113)
#   Region                                All%  Meta% Enrichment
#   ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-lh-caudalanteriorcingulate,10.0,Unk,2.0,PTD, 0.56   0.9%   6.7%      7.53x ***
#   Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,ctx-lh-precentral,3.0,PTD, -0.77   0.9%   6.7%      7.53x ***
#   Wm,69.0,ctx-lh-precentral,15.0,ctx-lh-caudalmiddlefrontal,9.0,Unk,4.0,ctx-lh-parsopercularis,2.0,PTD, -0.38   0.9%   5.0%      5.65x ***
#   Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-lh-rostralmiddlefrontal,2.0,PTD, -0.79   0.9%   5.0%      5.65x ***
#   Wm,90.0,ctx-lh-parsopercularis,10.0,PTD, -0.80   0.9%   5.0%      5.65x ***
#   ctx-lh-superiorfrontal,71.0,ctx-lh-caudalanteriorcingulate,13.0,Unk,9.0,Wm,7.0,PTD, 0.85   0.9%   5.0%      5.65x ***
#   ctx-lh-rostralmiddlefrontal,63.0,Unk,28.0,Wm,8.0,PTD, 0.84   0.9%   5.0%      5.65x ***
#   Wm,60.0,ctx-lh-superiorfrontal,37.0,ctx-lh-caudalanteriorcingulate,2.0,Unk,1.0,PTD, -0.20   0.9%   3.3%      3.77x ***
#   ctx-lh-rostralmiddlefrontal,59.0,Unk,41.0,PTD, 1.00   0.9%   3.3%      3.77x ***
#   Wm,38.0,ctx-lh-precentral,36.0,Unk,26.0,PTD, 0.24   0.9%   3.3%      3.77x ***
#   Wm,73.0,ctx-lh-rostralmiddlefrontal,27.0,PTD, -0.46   0.9%   3.3%      3.77x ***
#   Unk,91.0,ctx-lh-rostralmiddlefrontal,9.0,PTD, 1.00   0.9%   3.3%      3.77x ***
#   Wm,69.0,ctx-lh-parsopercularis,29.0,ctx-lh-rostralmiddlefrontal,2.0,PTD, -0.38   0.9%   3.3%      3.77x ***
#   ctx-lh-rostralmiddlefrontal,76.0,Unk,12.0,Wm,11.0,PTD, 0.77   0.9%   3.3%      3.77x ***
#   Unk,64.0,ctx-lh-rostralmiddlefrontal,36.0,PTD, 1.00   0.9%   3.3%      3.77x ***
#   Unk,63.0,ctx-lh-precentral,37.0,Wm,1.0,PTD, 0.98   0.9%   1.7%      1.88x **
#   ctx-lh-rostralmiddlefrontal,68.0,Unk,28.0,Wm,3.0,PTD, 0.93   0.9%   1.7%      1.88x **
#   ctx-lh-rostralmiddlefrontal,73.0,Unk,19.0,Wm,8.0,PTD, 0.84   0.9%   1.7%      1.88x **
#   Wm,100.0,PTD, -1.00                   3.5%   6.7%      1.88x **
#   Unk,99.0,ctx-lh-precentral,1.0,PTD, 1.00   0.9%   1.7%      1.88x **
#   Wm,65.0,ctx-lh-rostralmiddlefrontal,18.0,ctx-lh-parsopercularis,17.0,PTD, -0.30   0.9%   1.7%      1.88x **
#   Wm,70.0,ctx-lh-parsopercularis,28.0,WM-hypointensities,2.0,PTD, -0.40   0.9%   1.7%      1.88x **
#   Wm,72.0,ctx-lh-precentral,23.0,Unk,5.0,PTD, -0.45   0.9%   1.7%      1.88x **
#   ctx-lh-rostralmiddlefrontal,60.0,Wm,39.0,Unk,1.0,PTD, 0.22   0.9%   1.7%      1.88x **
#   ctx-lh-rostralmiddlefrontal,63.0,Wm,21.0,Unk,16.0,PTD, 0.58   0.9%   1.7%      1.88x **
#   Wm,89.0,ctx-lh-parstriangularis,11.0,PTD, -0.77   0.9%   1.7%      1.88x **
#   Wm,73.0,ctx-lh-parsopercularis,26.0,ctx-lh-insula,1.0,PTD, -0.46   0.9%   1.7%      1.88x **
#   Unk,78.0,ctx-lh-precentral,20.0,Wm,2.0,PTD, 0.97   0.9%   1.7%      1.88x **
#   Unk,100.0,PTD, 1.00                   7.1%   8.3%      1.18x
#
# Pat_08  (total channels with anatomy: 120)
#   Region                                All%  Meta% Enrichment
#   ctx-lh-middletemporal,85.0,Unk,11.0,Wm,5.0,PTD, 0.90   0.8%   5.0%      6.00x ***
#   Cerebellum-Cortex,82.0,Unk,14.0,ctx-lh-fusiform,3.0,ctx-lh-parahippocampal,1.0,PTD, 1.00   0.8%   5.0%      6.00x ***
#   ctx-lh-inferiortemporal,64.0,Unk,15.0,ctx-lh-middletemporal,13.0,Wm,7.0,PTD, 0.85   0.8%   3.3%      4.00x ***
#   Wm,88.0,ctx-lh-supramarginal,12.0,PTD, -0.76   0.8%   3.3%      4.00x ***
#   ctx-lh-insula,94.0,Wm,6.0,PTD, 0.89   0.8%   3.3%      4.00x ***
#   ctx-lh-supramarginal,50.0,Wm,30.0,Unk,20.0,PTD, 0.40   0.8%   3.3%      4.00x ***
#   Wm,67.0,ctx-lh-insula,28.0,ctx-lh-lateralorbitofrontal,5.0,PTD, -0.35   0.8%   3.3%      4.00x ***
#   ctx-lh-fusiform,72.0,Wm,27.0,ctx-lh-parahippocampal,1.0,PTD, 0.46   0.8%   3.3%      4.00x ***
#   ctx-lh-middletemporal,44.0,ctx-lh-inferiortemporal,12.0,PTD, 1.00   0.8%   3.3%      4.00x ***
#   Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0.98   1.7%   6.7%      4.00x ***
#   ctx-lh-fusiform,81.0,Unk,9.0,Cerebellum-Cortex,5.0,ctx-lh-parahippocampal,2.0,PTD, 0.95   0.8%   3.3%      4.00x ***
#   Wm,55.0,ctx-lh-fusiform,45.0,PTD, -0.11   0.8%   3.3%      4.00x ***
#   ctx-lh-supramarginal,43.0,Wm,41.0,Unk,15.0,PTD, 0.17   0.8%   3.3%      4.00x ***
#   Wm,60.0,ctx-lh-supramarginal,37.0,Unk,3.0,PTD, -0.20   0.8%   3.3%      4.00x ***
#   Hip,65.0,Wm,34.0,Inf-Lat-Vent,1.0,PTD, 0.32   0.8%   1.7%      2.00x **
#   Wm,99.0,Inf-Lat-Vent,1.0,PTD, -0.98   0.8%   1.7%      2.00x **
#   Unk,64.0,ctx-lh-parahippocampal,26.0,ctx-lh-entorhinal,10.0,PTD, 1.00   0.8%   1.7%      2.00x **
#   Wm,55.0,ctx-lh-superiortemporal,42.0,Unk,2.0,ctx-lh-transversetemporal,1.0,PTD, -0.11   0.8%   1.7%      2.00x **
#   ctx-lh-parahippocampal,48.0,Wm,36.0,ctx-lh-entorhinal,15.0,Hip,1.0,PTD, 0.28   0.8%   1.7%      2.00x **
#   ctx-lh-superiortemporal,57.0,Wm,43.0,PTD, 0.14   0.8%   1.7%      2.00x **
#   ctx-lh-middletemporal,54.0,Wm,43.0,Unk,3.0,PTD, 0.14   0.8%   1.7%      2.00x **
#   Wm,67.0,Hip,29.0,ctx-lh-parahippocampal,4.0,PTD, -0.33   0.8%   1.7%      2.00x **
#   Hip,69.0,Wm,31.0,PTD, 0.38            0.8%   1.7%      2.00x **
#   ctx-lh-superiortemporal,66.0,Wm,24.0,Unk,10.0,PTD, 0.51   0.8%   1.7%      2.00x **
#   Wm,50.0,Hip,28.0,Inf-Lat-Vent,20.0,ctx-lh-parahippocampal,1.0,PTD, -0.01   0.8%   1.7%      2.00x **
#   ctx-lh-middletemporal,56.0,Wm,44.0,PTD, 0.12   0.8%   1.7%      2.00x **
#   Unk,96.0,Amy,4.0,PTD, 1.00            0.8%   1.7%      2.00x **
#   ctx-lh-superiortemporal,63.0,Wm,30.0,Unk,7.0,PTD, 0.40   0.8%   1.7%      2.00x **
#   ctx-lh-middletemporal,65.0,Wm,20.0,Unk,12.0,ctx-lh-superiortemporal,3.0,PTD, 0.61   0.8%   1.7%      2.00x **
#   ctx-lh-bankssts,62.0,Wm,37.0,Unk,1.0,PTD, 0.25   0.8%   1.7%      2.00x **
#   Unk,92.0,ctx-lh-parstriangularis,8.0,PTD, 1.00   0.8%   1.7%      2.00x **
#   Unk,54.0,ctx-lh-postcentral,41.0,ctx-lh-transversetemporal,2.0,ctx-lh-precentral,2.0,ctx-lh-insula,1.0,PTD, 1.00   0.8%   1.7%      2.00x **
#   Wm,69.0,ctx-lh-bankssts,31.0,PTD, -0.38   0.8%   1.7%      2.00x **
#   ctx-lh-bankssts,78.0,Wm,16.0,Unk,6.0,PTD, 0.67   0.8%   1.7%      2.00x **
#   ctx-lh-fusiform,58.0,Wm,24.0,Unk,10.0,ctx-lh-parahippocampal,9.0,PTD, 0.53   0.8%   1.7%      2.00x **
#   Wm,74.0,ctx-lh-superiortemporal,25.0,Unk,1.0,PTD, -0.48   0.8%   1.7%      2.00x **
#   Unk,58.0,ctx-lh-parahippocampal,28.0,Cerebellum-Cortex,8.0,Wm,7.0,PTD, 0.87   0.8%   1.7%      2.00x **
#   ctx-lh-bankssts,69.0,Wm,25.0,Unk,6.0,PTD, 0.50   0.8%   1.7%      2.00x **
#   Wm,65.0,ctx-lh-parahippocampal,26.0,Hip,9.0,PTD, -0.30   0.8%   1.7%      2.00x **
#   Wm,49.0,ctx-lh-fusiform,36.0,Inf-Lat-Vent,7.0,Hip,5.0,ctx-lh-entorhinal,2.0,Unk,1.0,PTD, 0.02   0.8%   1.7%      2.00x **
#   ctx-lh-superiortemporal,51.0,Wm,49.0,PTD, 0.02   0.8%   1.7%      2.00x **
#   Wm,45.0,ctx-lh-entorhinal,30.0,Hip,20.0,Inf-Lat-Vent,4.0,ctx-lh-fusiform,2.0,PTD, 0.11   0.8%   1.7%      2.00x **

# %% [markdown]
# ## Node strength vs metastability
#
# Are metastable nodes hubs (high strength) or peripheral (low strength)?

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(len(patients), len(bands), figsize=(16, 4 * len(patients)),
                          squeeze=False)
fig.suptitle('Node strength vs metastability (mu)', fontsize=14, y=1.01)

for pi, patient in enumerate(patients):
    epi_set = set(load_epileptic_nodes(patient))
    ch = load_ch(patient)
    N = len(ch)
    epi_mask = np.array([l in epi_set for l in ch])
    
    for bi, band in enumerate(bands):
        ax = axes[pi, bi]
        
        A = load_msc_matrix(patient, 'rsPre', band,
                            cache_root=Path('data/msc_cache'),
                            sparsify='none', n_surrogates=0, nperseg=4096)
        if A is None or A.shape[0] != N:
            ax.set_visible(False)
            continue
        
        A_copy = A.copy()
        np.fill_diagonal(A_copy, 0)
        D = A_copy.sum(axis=1)
        L = np.diag(D) - A_copy
        evals, evecs = np.linalg.eigh(L)
        evals = np.maximum(evals, 0.0)
        if evals[1] < 1e-10:
            ax.set_visible(False)
            continue
        
        result = compute_coarsening_and_metastability(evals, evecs, n_tau=40)
        mu = result['mu']
        
        # Scatter: non-epileptic in blue, epileptic in red
        ax.scatter(D[~epi_mask], mu[~epi_mask], alpha=0.4, s=15, c='steelblue',
                   label='non-EPI')
        ax.scatter(D[epi_mask], mu[epi_mask], alpha=0.7, s=25, c='red',
                   marker='^', label='EPI')
        
        # Correlation
        corr = np.corrcoef(D, mu)[0, 1]
        ax.set_title(f'{patient} {band}\nr={corr:.2f}', fontsize=9)
        ax.set_xlabel('Strength' if pi == len(patients) - 1 else '')
        ax.set_ylabel('mu' if bi == 0 else '')
        if pi == 0 and bi == 0:
            ax.legend(fontsize=7)

fig.tight_layout()
plt.show()
plt.close(fig)

# %% [markdown]
# ## Band consistency: are the same nodes metastable across frequency bands?

# %%
print("=== Band consistency: how often does a node appear in top-15 across bands? ===\n")

for patient in patients:
    sub = df[df['patient'] == patient]
    label_band_counts = sub.groupby('label')['band'].nunique()
    
    # Nodes appearing in top-15 for multiple bands
    multi_band = label_band_counts[label_band_counts > 1]
    
    print(f"{patient}:")
    print(f"  Unique nodes in top-15 across all bands: {sub['label'].nunique()}")
    print(f"  Nodes in top-15 for >=2 bands: {len(multi_band)}")
    if len(multi_band) > 0:
        for label, count in multi_band.sort_values(ascending=False).items():
            bands_for_label = sub[sub['label'] == label]['band'].tolist()
            anat = sub[sub['label'] == label]['anatomy'].iloc[0]
            is_epi = sub[sub['label'] == label]['is_epi'].iloc[0]
            epi_str = ' [EPI]' if is_epi else ''
            print(f"    {label}: {count} bands ({', '.join(bands_for_label)}) "
                  f"— {anat}{epi_str}")
    print()
# Out:
# === Band consistency: how often does a node appear in top-15 across bands? ===
#
# Pat_02:
#   Unique nodes in top-15 across all bands: 41
#   Nodes in top-15 for >=2 bands: 15
#     F3: 3 bands (delta, alpha, beta) — ctx-lh-lateralorbitofrontal,45.0,ctx-lh-medialorbitofrontal,34.0,Wm,20.0,Unk,2.0,PTD, 0.61
#     F8: 3 bands (theta, alpha, beta) — ctx-lh-lateralorbitofrontal,65.0,Wm,35.0,PTD, 0.30
#     F4: 3 bands (theta, alpha, beta) — ctx-lh-lateralorbitofrontal,50.0,Wm,48.0,ctx-lh-medialorbitofrontal,2.0,PTD, 0.04
#     H16: 3 bands (theta, alpha, beta) — Unk,100.0,PTD, 1.00
#     B3: 2 bands (delta, beta) — ctx-lh-fusiform,67.0,Wm,33.0,PTD, 0.33
#     B1: 2 bands (delta, theta) — Cerebellum-Cortex,30.0,ctx-lh-parahippocampal,26.0,ctx-lh-lingual,19.0,Unk,15.0,ctx-lh-fusiform,10.0,PTD, 1.00
#     A8: 2 bands (delta, theta) — ctx-lh-fusiform,79.0,ctx-lh-inferiortemporal,11.0,Unk,7.0,Wm,3.0,PTD, 0.93
#     F14: 2 bands (theta, alpha) — Unk,86.0,ctx-lh-parsorbitalis,14.0,PTD, 1.00
#     F1: 2 bands (delta, theta) — ctx-lh-medialorbitofrontal,79.0,Wm,14.0,Unk,7.0,PTD, 0.72
#     B4: 2 bands (delta, beta) — Wm,59.0,ctx-lh-fusiform,41.0,PTD, -0.19
#     G7: 2 bands (alpha, beta) — Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD, -0.69
#     L12: 2 bands (theta, beta) — Unk,67.0,ctx-lh-middletemporal,33.0,PTD, 1.00
#     M3: 2 bands (theta, alpha) — ctx-lh-superiortemporal,55.0,Wm,44.0,Unk,1.0,PTD, 0.12
#     M8: 2 bands (delta, theta) — ctx-lh-superiortemporal,49.0,ctx-lh-middletemporal,38.0,Unk,12.0,Wm,1.0,PTD, 0.98
#     N4: 2 bands (theta, alpha) — ctx-lh-bankssts,62.0,Unk,37.0,Wm,1.0,PTD, 0.98
#
# Pat_03:
#   Unique nodes in top-15 across all bands: 47
#   Nodes in top-15 for >=2 bands: 11
#     P3: 3 bands (delta, theta, beta) — ctx-lh-cuneus,60.0,ctx-lh-precuneus,25.0,Unk,11.0,Wm,4.0,PTD, 0.92
#     P4: 3 bands (delta, theta, beta) — ctx-lh-precuneus,77.0,Unk,14.0,ctx-lh-cuneus,6.0,Wm,3.0,PTD, 0.93
#     D10: 2 bands (delta, alpha) — ctx-lh-middletemporal,92.0,Wm,8.0,PTD, 0.84
#     D4: 2 bands (delta, alpha) — Wm,65.0,ctx-lh-fusiform,34.0,ctx-lh-inferiortemporal,1.0,PTD, -0.30
#     D2: 2 bands (delta, alpha) — ctx-lh-entorhinal,59.0,Wm,32.0,ctx-lh-fusiform,8.0,Unk,1.0,PTD, 0.37
#     D5: 2 bands (delta, alpha) — Wm,54.0,ctx-lh-inferiortemporal,34.0,ctx-lh-fusiform,11.0,PTD, -0.09
#     D6: 2 bands (delta, alpha) — ctx-lh-inferiortemporal,85.0,ctx-lh-middletemporal,7.0,Wm,6.0,Unk,2.0,PTD, 0.89
#     D8: 2 bands (delta, alpha) — ctx-lh-inferiortemporal,46.0,ctx-lh-middletemporal,38.0,Unk,15.0,Wm,1.0,PTD, 0.98
#     D7: 2 bands (delta, alpha) — ctx-lh-inferiortemporal,57.0,ctx-lh-middletemporal,33.0,Unk,11.0,PTD, 1.00
#     E7: 2 bands (theta, beta) — Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD, -0.69
#     D9: 2 bands (alpha, beta) — ctx-lh-middletemporal,68.0,ctx-lh-inferiortemporal,24.0,Wm,7.0,Unk,1.0,PTD, 0.87
#
# Pat_05:
#   Unique nodes in top-15 across all bands: 36
#   Nodes in top-15 for >=2 bands: 20
#     X'8: 3 bands (theta, alpha, beta) — ctx-lh-rostralmiddlefrontal,55.0,Wm,37.0,Unk,7.0,ctx-lh-superiorfrontal,2.0,PTD, 0.27
#     Y'10: 3 bands (delta, theta, alpha) — ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,Unk,15.0,PTD, 0.30
#     Y'9: 3 bands (delta, theta, alpha) — ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,Unk,8.0,PTD, 0.09
#     G9: 3 bands (theta, alpha, beta) — ctx-rh-medialorbitofrontal,52.0,ctx-rh-rostralanteriorcingulate,28.0,Unk,14.0,Wm,6.0,PTD, 0.89
#     G3: 2 bands (theta, alpha) — Wm,50.0,ctx-rh-medialorbitofrontal,50.0,PTD, -0.01
#     G2: 2 bands (theta, alpha) — ctx-rh-medialorbitofrontal,61.0,Wm,37.0,Unk,2.0,PTD, 0.25
#     G13: 2 bands (delta, beta) — ctx-rh-superiorfrontal,49.0,Wm,46.0,Unk,6.0,PTD, 0.09
#     F1: 2 bands (theta, alpha) — ctx-rh-medialorbitofrontal,68.0,Unk,31.0,Wm,1.0,PTD, 0.98
#     G7: 2 bands (theta, alpha) — ctx-rh-rostralanteriorcingulate,56.0,Wm,23.0,ctx-rh-medialorbitofrontal,12.0,Unk,9.0,PTD, 0.54
#     G4: 2 bands (theta, alpha) — ctx-rh-medialorbitofrontal,55.0,Wm,44.0,ctx-rh-rostralanteriorcingulate,1.0,PTD, 0.12
#     G6: 2 bands (theta, alpha) — ctx-rh-rostralanteriorcingulate,45.0,ctx-rh-medialorbitofrontal,32.0,Unk,14.0,Wm,10.0,PTD, 0.80
#     G5: 2 bands (theta, alpha) — ctx-rh-medialorbitofrontal,63.0,ctx-rh-rostralanteriorcingulate,19.0,Unk,12.0,Wm,6.0,PTD, 0.89
#     O11: 2 bands (delta, beta) — ctx-rh-rostralmiddlefrontal,65.0,Wm,20.0,Unk,15.0,PTD, 0.59
#     O10: 2 bands (delta, beta) — ctx-rh-rostralmiddlefrontal,50.0,Wm,41.0,Unk,8.0,PTD, 0.17
#     G8: 2 bands (theta, alpha) — ctx-rh-medialorbitofrontal,53.0,ctx-rh-rostralanteriorcingulate,35.0,Wm,12.0,PTD, 0.76
#     X'10: 2 bands (theta, alpha) — Wm,59.0,ctx-lh-rostralmiddlefrontal,41.0,PTD, -0.19
#     X'9: 2 bands (theta, alpha) — Wm,68.0,ctx-lh-rostralmiddlefrontal,32.0,PTD, -0.37
#     X'11: 2 bands (theta, alpha) — ctx-lh-rostralmiddlefrontal,79.0,Wm,21.0,PTD, 0.58
#     Y4: 2 bands (delta, beta) — Wm,90.0,ctx-rh-superiorfrontal,10.0,PTD, -0.80
#     Y5: 2 bands (delta, beta) — Wm,53.0,ctx-rh-superiorfrontal,46.0,Unk,1.0,PTD, -0.06
#
# Pat_07:
#   Unique nodes in top-15 across all bands: 33
#   Nodes in top-15 for >=2 bands: 18
#     X3: 4 bands (delta, theta, alpha, beta) — Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,ctx-lh-precentral,3.0,PTD, -0.77
#     F2: 4 bands (delta, theta, alpha, beta) — ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-lh-caudalanteriorcingulate,10.0,Unk,2.0,PTD, 0.56
#     X2: 3 bands (delta, alpha, beta) — Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-lh-rostralmiddlefrontal,2.0,PTD, -0.79
#     A1: 3 bands (delta, theta, alpha) — Wm,90.0,ctx-lh-parsopercularis,10.0,PTD, -0.80 [EPI]
#     F1: 3 bands (delta, theta, alpha) — ctx-lh-superiorfrontal,71.0,ctx-lh-caudalanteriorcingulate,13.0,Unk,9.0,Wm,7.0,PTD, 0.85
#     A9: 3 bands (delta, theta, alpha) — ctx-lh-rostralmiddlefrontal,63.0,Unk,28.0,Wm,8.0,PTD, 0.84
#     X4: 3 bands (delta, theta, alpha) — Wm,69.0,ctx-lh-precentral,15.0,ctx-lh-caudalmiddlefrontal,9.0,Unk,4.0,ctx-lh-parsopercularis,2.0,PTD, -0.38
#     A10: 2 bands (delta, alpha) — Unk,91.0,ctx-lh-rostralmiddlefrontal,9.0,PTD, 1.00
#     F4: 2 bands (delta, alpha) — Wm,100.0,PTD, -1.00
#     F3: 2 bands (delta, alpha) — Wm,60.0,ctx-lh-superiorfrontal,37.0,ctx-lh-caudalanteriorcingulate,2.0,Unk,1.0,PTD, -0.20
#     L2: 2 bands (theta, beta) — Wm,69.0,ctx-lh-parsopercularis,29.0,ctx-lh-rostralmiddlefrontal,2.0,PTD, -0.38
#     F6: 2 bands (delta, alpha) — Wm,73.0,ctx-lh-rostralmiddlefrontal,27.0,PTD, -0.46
#     F5: 2 bands (delta, alpha) — Wm,100.0,PTD, -1.00
#     M8: 2 bands (theta, beta) — ctx-lh-rostralmiddlefrontal,59.0,Unk,41.0,PTD, 1.00
#     U12: 2 bands (delta, alpha) — Unk,100.0,PTD, 1.00
#     U11: 2 bands (delta, alpha) — Unk,64.0,ctx-lh-rostralmiddlefrontal,36.0,PTD, 1.00
#     U10: 2 bands (delta, alpha) — ctx-lh-rostralmiddlefrontal,76.0,Unk,12.0,Wm,11.0,PTD, 0.77
#     X6: 2 bands (theta, beta) — Wm,38.0,ctx-lh-precentral,36.0,Unk,26.0,PTD, 0.24
#
# Pat_08:
#   Unique nodes in top-15 across all bands: 43
#   Nodes in top-15 for >=2 bands: 15
#     D12: 3 bands (delta, alpha, beta) — ctx-lh-middletemporal,85.0,Unk,11.0,Wm,5.0,PTD, 0.90
#     F1: 3 bands (delta, alpha, beta) — Cerebellum-Cortex,82.0,Unk,14.0,ctx-lh-fusiform,3.0,ctx-lh-parahippocampal,1.0,PTD, 1.00
#     D10: 2 bands (delta, alpha) — ctx-lh-inferiortemporal,64.0,Unk,15.0,ctx-lh-middletemporal,13.0,Wm,7.0,PTD, 0.85
#     D11: 2 bands (delta, alpha) — ctx-lh-middletemporal,44.0,ctx-lh-inferiortemporal,12.0,PTD, 1.00
#     F2: 2 bands (delta, alpha) — ctx-lh-fusiform,81.0,Unk,9.0,Cerebellum-Cortex,5.0,ctx-lh-parahippocampal,2.0,PTD, 0.95
#     F3: 2 bands (delta, alpha) — ctx-lh-fusiform,72.0,Wm,27.0,ctx-lh-parahippocampal,1.0,PTD, 0.46
#     F4: 2 bands (delta, alpha) — Wm,55.0,ctx-lh-fusiform,45.0,PTD, -0.11
#     P11: 2 bands (delta, alpha) — Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0.98
#     P12: 2 bands (delta, alpha) — Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0.98
#     P13: 2 bands (delta, alpha) — Wm,88.0,ctx-lh-supramarginal,12.0,PTD, -0.76
#     P14: 2 bands (delta, alpha) — Wm,60.0,ctx-lh-supramarginal,37.0,Unk,3.0,PTD, -0.20
#     P15: 2 bands (delta, alpha) — ctx-lh-supramarginal,50.0,Wm,30.0,Unk,20.0,PTD, 0.40
#     P16: 2 bands (delta, alpha) — ctx-lh-supramarginal,43.0,Wm,41.0,Unk,15.0,PTD, 0.17
#     R1: 2 bands (delta, alpha) — Wm,67.0,ctx-lh-insula,28.0,ctx-lh-lateralorbitofrontal,5.0,PTD, -0.35
#     R2: 2 bands (delta, alpha) — ctx-lh-insula,94.0,Wm,6.0,PTD, 0.89

# %% [markdown]
# ## Summary table

# %%
# Final summary table
print("=" * 80)
print("SUMMARY: What characterizes the most metastable nodes?")
print("=" * 80)

# 1. Epileptic
n_epi_meta = df['is_epi'].sum()
n_total_meta = len(df)
print(f"\n1. EPILEPTIC STATUS")
print(f"   {n_epi_meta}/{n_total_meta} ({100*n_epi_meta/n_total_meta:.1f}%) of top-{TOP_K} "
      f"metastable nodes are epileptic")
print(f"   Baseline epileptic fraction: ~{100*np.mean(baseline_epi_fracs):.1f}%")

# 2. Anatomy
print(f"\n2. ANATOMICAL REGIONS (most common in top metastable)")
known = df[df['anatomy'] != '?']
if len(known) > 0:
    top_regions = known['anatomy'].value_counts().head(10)
    for region, count in top_regions.items():
        print(f"   {region}: {count} ({100*count/len(known):.1f}%)")

# 3. Strength
print(f"\n3. NODE STRENGTH")
print(f"   Mean strength of top-metastable: {df['strength'].mean():.2f}")

# 4. Probe boundaries
print(f"\n4. PROBE BOUNDARIES")
print(f"   {total_boundary}/{total_n} ({100*total_boundary/total_n:.1f}%) of top-metastable "
      f"are first/last contacts on their probe")

# 5. Band consistency
multi_band_total = 0
unique_total = 0
for patient in patients:
    sub = df[df['patient'] == patient]
    label_band_counts = sub.groupby('label')['band'].nunique()
    multi_band_total += (label_band_counts > 1).sum()
    unique_total += len(label_band_counts)
print(f"\n5. BAND CONSISTENCY")
print(f"   {multi_band_total}/{unique_total} ({100*multi_band_total/unique_total:.1f}%) of "
      f"unique metastable nodes appear in top-{TOP_K} for multiple bands")
# Out:
# ================================================================================
# SUMMARY: What characterizes the most metastable nodes?
# ================================================================================
#
# 1. EPILEPTIC STATUS
#    19/300 (6.3%) of top-15 metastable nodes are epileptic
#    Baseline epileptic fraction: ~8.5%
#
# 2. ANATOMICAL REGIONS (most common in top metastable)
#    Unk,100.0,PTD, 1.00: 8 (2.7%)
#    Wm,100.0,PTD, -1.00: 5 (1.7%)
#    Wm,99.0,ctx-lh-supramarginal,1.0,PTD, -0.98: 4 (1.3%)
#    Wm,85.0,ctx-lh-inferiortemporal,15.0,PTD, -0.69: 4 (1.3%)
#    ctx-lh-superiorfrontal,66.0,Wm,22.0,ctx-lh-caudalanteriorcingulate,10.0,Unk,2.0,PTD, 0.56: 4 (1.3%)
#    Wm,89.0,ctx-lh-caudalmiddlefrontal,8.0,ctx-lh-precentral,3.0,PTD, -0.77: 4 (1.3%)
#    Wm,90.0,ctx-lh-parsopercularis,10.0,PTD, -0.80: 3 (1.0%)
#    ctx-lh-caudalmiddlefrontal,50.0,Wm,35.0,Unk,15.0,PTD, 0.30: 3 (1.0%)
#    ctx-lh-caudalmiddlefrontal,46.0,Wm,46.0,Unk,8.0,PTD, 0.09: 3 (1.0%)
#    Wm,89.0,ctx-lh-parsopercularis,9.0,ctx-lh-rostralmiddlefrontal,2.0,PTD, -0.79: 3 (1.0%)
#
# 3. NODE STRENGTH
#    Mean strength of top-metastable: 24.02
#
# 4. PROBE BOUNDARIES
#    62/300 (20.7%) of top-metastable are first/last contacts on their probe
#
# 5. BAND CONSISTENCY
#    79/200 (39.5%) of unique metastable nodes appear in top-15 for multiple bands
